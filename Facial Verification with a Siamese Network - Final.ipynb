# %% [markdown]
# # 1. Setup

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python matplotlib

import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# Import tensorflow dependencies - Functional API
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

## 1.3 Set GPU Growth

# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

## 1.4 Create Folder Structures

# Setup paths
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# Make the directories
os.makedirs(POS_PATH, exist_ok=True)
os.makedirs(NEG_PATH, exist_ok=True)
os.makedirs(ANC_PATH, exist_ok=True)


# 2. Collect Positives and Anchors

## 2.1 Untar Labelled Faces in the Wild Dataset

# http://vis-www.cs.umass.edu/lfw/

# Uncompress Tar GZ Labelled Faces in the Wild Dataset
# !tar -xf lfw.tgz

# Move LFW Images to the following repository data/negative
# for directory in os.listdir('lfw'):
#     for file in os.listdir(os.path.join('lfw', directory)):
#         EX_PATH = os.path.join('lfw', directory, file)
#         NEW_PATH = os.path.join(NEG_PATH, file)
#         os.replace(EX_PATH, NEW_PATH)

for file in os.listdir(NEG_PATH):
    print(os.path.join(NEG_PATH, file))

## 2.2 Collect Positive and Anchor Classes

# Import uuid library to generate unique image names
# universally unique identifiers
import uuid

uuid.uuid1()

os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))

# Establish a connection to the webcam
cap = cv2.VideoCapture(0)
while cap.isOpened(): 
    ret, frame = cap.read()
   
    # Cut down frame to 250x250px
    frame = frame[120:120+250,200:200+250, :]
    
    # Collect anchors 
    if cv2.waitKey(1) & 0XFF == ord('a'):
        # Create the unique file path 
        imgname = os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out anchor image
        cv2.imwrite(imgname, frame)
    
    # Collect positives
    if cv2.waitKey(1) & 0XFF == ord('p'):
        # Create the unique file path 
        imgname = os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out positive image
        cv2.imwrite(imgname, frame)
    
    # Show image back to screen
    cv2.imshow('Image Collection', frame)
    
    # Breaking gracefully
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
        
# Release the webcam
cap.release()
# Close the image show frame
cv2.destroyAllWindows()

plt.imshow(frame[:250,:250, :])
# frame.shape

# 2.x NEW - Data Augmentation

def data_aug(img):
    data = []
    for i in range(9):
        img = tf.image.stateless_random_brightness(img, max_delta=0.02, seed=(1,2))
        img = tf.image.stateless_random_contrast(img, lower=0.6, upper=1, seed=(1,3))
        # img = tf.image.stateless_random_crop(img, size=(20,20,3), seed=(1,2))
        img = tf.image.stateless_random_flip_left_right(img, seed=(np.random.randint(100),np.random.randint(100)))
        img = tf.image.stateless_random_jpeg_quality(img, min_jpeg_quality=90, max_jpeg_quality=100, seed=(np.random.randint(100),np.random.randint(100)))
        img = tf.image.stateless_random_saturation(img, lower=0.9,upper=1, seed=(np.random.randint(100),np.random.randint(100)))
            
        data.append(img)
    
    return data

import os
import uuid

# img_path = os.path.join(ANC_PATH, '924e839c-135f-11ec-b54e-a0cec8d2d278.jpg')
# img = cv2.imread(img_path)
# augmented_images = data_aug(img)

# for image in augmented_images:
#     cv2.imwrite(os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1())), image.numpy())

# for file_name in os.listdir(os.path.join(POS_PATH)):
#     img_path = os.path.join(POS_PATH, file_name)
#     img = cv2.imread(img_path)
#     augmented_images = data_aug(img) 
    
#     for image in augmented_images:
#         cv2.imwrite(os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1())), image.numpy())

# 3. Load and Preprocess Images

## 3.1 Get Image Directories

anchor = tf.data.Dataset.list_files(ANC_PATH+'\*.jpg').take(30)
positive = tf.data.Dataset.list_files(POS_PATH+'\*.jpg').take(30)
negative = tf.data.Dataset.list_files(NEG_PATH+'\*.jpg').take(30)

dir_test = anchor.as_numpy_iterator()

print(dir_test.next())

## 3.2 Preprocessing - Scale and Resize

def preprocess(file_path):
    
    # Read in image from file path
    byte_img = tf.io.read_file(file_path)
    # Load in the image 
    img = tf.io.decode_jpeg(byte_img)
    
    # Preprocessing steps - resizing the image to be 100x100x3
    img = tf.image.resize(img, (100,100))
    # Scale image to be between 0 and 1 
    img = img / 255.0

    # Return image
    return img

img = preprocess('data\\anchor\\a2c8f0b5-120e-11ee-bb7e-ab6017e68633.jpg')
img

plt.imshow(img)

img.numpy().min() 

# dataset.map(preprocess)

## 3.3 Create Labelled Dataset

# (anchor, positive) => 1,1,1,1,1
# (anchor, negative) => 0,0,0,0,0
tf.ones(len(anchor))

class_labels=tf.data.Dataset.from_tensor_slices(tf.zeros(len(anchor)))

iterator_labs=class_labels.as_numpy_iterator()

iterator_labs.next()

positives = tf.data.Dataset.zip((anchor, positive, tf.data.Dataset.from_tensor_slices(tf.ones(len(anchor)))))
negatives = tf.data.Dataset.zip((anchor, negative, tf.data.Dataset.from_tensor_slices(tf.zeros(len(anchor)))))
data = positives.concatenate(negatives)

samples = data.as_numpy_iterator()

exampple = samples.next()

exampple

## 3.4 Build Train and Test Partition

def preprocess_twin(input_img, validation_img, label):
    return(preprocess(input_img), preprocess(validation_img), label)

res = preprocess_twin(*exampple)
len(res)
res[0]

plt.imshow(res[0])

plt.imshow(res[1])

res[2]

# Build dataloader pipeline
data = data.map(preprocess_twin)
data = data.cache()
data = data.shuffle(buffer_size=10000)

# data

samples=data.as_numpy_iterator()

samp=samples.next()

plt.imshow(samp[1])

round(len(data)*0.7)

data

# Training partition
train_data = data.take(round(len(data)*.7))
train_data = train_data.batch(16)
train_data = train_data.prefetch(8)

len(train_data)

train_data

train_samples=train_data.as_numpy_iterator()

train_sample=train_samples.next()

len(train_sample[0])

# Testing partition
test_data = data.skip(round(len(data)*.7))
test_data = test_data.take(round(len(data)*.3))
test_data = test_data.batch(16)
test_data = test_data.prefetch(8)

# 4. Model Engineering

## 4.1 Build Embedding Layer

inp = Input(shape=(100,100,3), name='input_image')
inp

c1 = Conv2D(64, (10,10), activation='relu')(inp)
c1

m1 = MaxPooling2D(64, (2,2), padding='same')(c1)
m1

c2 = Conv2D(128, (7,7), activation='relu')(m1)
m2 = MaxPooling2D(64, (2,2), padding='same')(c2)

c3 = Conv2D(128, (4,4), activation='relu')(m2)
m3 = MaxPooling2D(64, (2,2), padding='same')(c3)

c4 = Conv2D(256, (4,4), activation='relu')(m3)
f1 = Flatten()(c4)
d1 = Dense(4096, activation='sigmoid')(f1)

mod = Model(inputs=[inp], outputs=[d1], name='embedding')

mod.summary()

def make_embedding(): 
    inp = Input(shape=(100,100,3), name='input_image')
    
    # First block
    c1 = Conv2D(64, (10,10), activation='relu')(inp)
    m1 = MaxPooling2D(64, (2,2), padding='same')(c1)
    
    # Second block
    c2 = Conv2D(128, (7,7), activation='relu')(m1)
    m2 = MaxPooling2D(64, (2,2), padding='same')(c2)
    
    # Third block 
    c3 = Conv2D(128, (4,4), activation='relu')(m2)
    m3 = MaxPooling2D(64, (2,2), padding='same')(c3)
    
    # Final embedding block
    c4 = Conv2D(256, (4,4), activation='relu')(m3)
    f1 = Flatten()(c4)
    d1 = Dense(4096, activation='sigmoid')(f1)
    
    
    return Model(inputs=[inp], outputs=[d1], name='embedding')

embedding = make_embedding()

embedding.summary()

## 4.2 Build Distance Layer

# Siamese L1 Distance class
class L1Dist(Layer):
    
    # Init method - inheritance
    def __init__(self, **kwargs):
        super().__init__()
       
    # Magic happens here - similarity calculation
    def call(self, input_embedding, validation_embedding):
        return tf.math.abs(input_embedding - validation_embedding)

l1 = L1Dist()

# l1(anchor_embedding, validation_embedding)

## 4.3 Make Siamese Model

input_image = Input(name='input_img', shape=(100,100,3))
validation_image = Input(name='validation_img', shape=(100,100,3))

inp_embedding = embedding(input_image)
val_embedding = embedding(validation_image)

siamese_layer = L1Dist()

distances = siamese_layer(inp_embedding, val_embedding)

classifier = Dense(1, activation='sigmoid')(distances)

classifier

siamese_network = Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')

siamese_network.summary()

def make_siamese_model(): 
    
    # Anchor image input in the network
    input_image = Input(name='input_img', shape=(100,100,3))
    
    # Validation image in the network 
    validation_image = Input(name='validation_img', shape=(100,100,3))
    
    # Combine siamese distance components
    siamese_layer = L1Dist()
    siamese_layer._name = 'distance'
    distances = siamese_layer(embedding(input_image), embedding(validation_image))
    
    # Classification layer 
    classifier = Dense(1, activation='sigmoid')(distances)
    
    return Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')

siamese_model = make_siamese_model()

siamese_model.summary()

# 5. Training

## 5.1 Setup Loss and Optimizer

binary_cross_loss = tf.losses.BinaryCrossentropy()

opt = tf.keras.optimizers.Adam(1e-4) # 0.0001

## 5.2 Establish Checkpoints

checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(opt=opt, siamese_model=siamese_model)

## 5.3 Build Train Step Function

test_batch = train_data.as_numpy_iterator()

batch_1 = test_batch.next()
batch_1

len(batch_1[0])

batch_1[0].shape

X = batch_1[:2]
X

np.array(X).shape

y = batch_1[2]

y

# tf.losses.BinaryCrossentropy??

@tf.function
def train_step(batch):
    
    # Record all of our operations 
    with tf.GradientTape() as tape:     
        # Get anchor and positive/negative image
        X = batch[:2]
        # Get label
        y = batch[2]
        
        # Forward pass
        yhat = siamese_model(X, training=True)
        # Calculate loss
        loss = binary_cross_loss(y, yhat)
    print(loss)
        
    # Calculate gradients
    grad = tape.gradient(loss, siamese_model.trainable_variables)
    
    # Calculate updated weights and apply to siamese model
    opt.apply_gradients(zip(grad, siamese_model.trainable_variables))
        
    # Return loss
    return loss

## 5.4 Build Training Loop

# Import metric calculations
from tensorflow.keras.metrics import Precision, Recall

def train(data, EPOCHS):
    # Loop through epochs
    for epoch in range(1, EPOCHS+1):
        print('\n Epoch {}/{}'.format(epoch, EPOCHS))
        progbar = tf.keras.utils.Progbar(len(data))
        
        # Creating a metric object 
        r = Recall()
        p = Precision()
        
        # Loop through each batch
        for idx, batch in enumerate(data):
            # Run train step here
            loss = train_step(batch)
            yhat = siamese_model.predict(batch[:2])
            r.update_state(batch[2], yhat)
            p.update_state(batch[2], yhat) 
            progbar.update(idx+1)
        print(loss.numpy(), r.result().numpy(), p.result().numpy())
        
        # Save checkpoints
        if epoch % 10 == 0: 
            checkpoint.save(file_prefix=checkpoint_prefix)

## 5.5 Train the model

EPOCHS = 50

train(train_data, EPOCHS)
# Out:
# data\negative\Aaron_Eckhart_0001.jpg
# data\negative\Aaron_Guiel_0001.jpg
# data\negative\Aaron_Patterson_0001.jpg
# data\negative\Aaron_Peirsol_0001.jpg
# data\negative\Aaron_Peirsol_0002.jpg
# data\negative\Aaron_Peirsol_0003.jpg
# data\negative\Aaron_Peirsol_0004.jpg
# data\negative\Aaron_Pena_0001.jpg
# data\negative\Aaron_Sorkin_0001.jpg
# data\negative\Aaron_Sorkin_0002.jpg
# data\negative\Aaron_Tippin_0001.jpg
# data\negative\Abbas_Kiarostami_0001.jpg
# data\negative\Abba_Eban_0001.jpg
# data\negative\Abdel_Aziz_Al-Hakim_0001.jpg
# data\negative\Abdel_Madi_Shabneh_0001.jpg
# data\negative\Abdel_Nasser_Assidi_0001.jpg
# data\negative\Abdel_Nasser_Assidi_0002.jpg
# data\negative\Abdoulaye_Wade_0001.jpg
# data\negative\Abdoulaye_Wade_0002.jpg
# data\negative\Abdoulaye_Wade_0003.jpg
# data\negative\Abdoulaye_Wade_0004.jpg
# data\negative\Abdulaziz_Kamilov_0001.jpg
# data\negative\Abdullah_0001.jpg
# data\negative\Abdullah_0002.jpg
# data\negative\Abdullah_0003.jpg
# data\negative\Abdullah_0004.jpg
# data\negative\Abdullah_Ahmad_Badawi_0001.jpg
# data\negative\Abdullah_al-Attiyah_0001.jpg
# data\negative\Abdullah_al-Attiyah_0002.jpg
# data\negative\Abdullah_al-Attiyah_0003.jpg
# data\negative\Abdullah_Gul_0001.jpg
# data\negative\Abdullah_Gul_0002.jpg
# data\negative\Abdullah_Gul_0003.jpg
# data\negative\Abdullah_Gul_0004.jpg
# data\negative\Abdullah_Gul_0005.jpg
# data\negative\Abdullah_Gul_0006.jpg
# data\negative\Abdullah_Gul_0007.jpg
# data\negative\Abdullah_Gul_0008.jpg
# data\negative\Abdullah_Gul_0009.jpg
# data\negative\Abdullah_Gul_0010.jpg
# data\negative\Abdullah_Gul_0011.jpg
# data\negative\Abdullah_Gul_0012.jpg
# data\negative\Abdullah_Gul_0013.jpg
# data\negative\Abdullah_Gul_0014.jpg
# data\negative\Abdullah_Gul_0015.jpg
# data\negative\Abdullah_Gul_0016.jpg
# data\negative\Abdullah_Gul_0017.jpg
# data\negative\Abdullah_Gul_0018.jpg
# data\negative\Abdullah_Gul_0019.jpg
# data\negative\Abdullah_Nasseef_0001.jpg
# data\negative\Abdullatif_Sener_0001.jpg
# data\negative\Abdullatif_Sener_0002.jpg
# data\negative\Abdul_Majeed_Shobokshi_0001.jpg
# data\negative\Abdul_Rahman_0001.jpg
# data\negative\Abel_Aguilar_0001.jpg
# data\negative\Abel_Pacheco_0001.jpg
# data\negative\Abel_Pacheco_0002.jpg
# data\negative\Abel_Pacheco_0003.jpg
# data\negative\Abel_Pacheco_0004.jpg
# data\negative\Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg
# data\negative\Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg
# data\negative\Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg
# data\negative\Abner_Martinez_0001.jpg
# data\negative\Abraham_Foxman_0001.jpg
# data\negative\Aby_Har-Even_0001.jpg
# data\negative\Adam_Ant_0001.jpg
# data\negative\Adam_Freier_0001.jpg
# data\negative\Adam_Herbert_0001.jpg
# data\negative\Adam_Kennedy_0001.jpg
# data\negative\Adam_Mair_0001.jpg
# data\negative\Adam_Rich_0001.jpg
# data\negative\Adam_Sandler_0001.jpg
# data\negative\Adam_Sandler_0002.jpg
# data\negative\Adam_Sandler_0003.jpg
# data\negative\Adam_Sandler_0004.jpg
# data\negative\Adam_Scott_0001.jpg
# data\negative\Adam_Scott_0002.jpg
# data\negative\Adelina_Avila_0001.jpg
# data\negative\Adel_Al-Jubeir_0001.jpg
# data\negative\Adel_Al-Jubeir_0002.jpg
# data\negative\Adel_Al-Jubeir_0003.jpg
# data\negative\Adisai_Bodharamik_0001.jpg
# data\negative\Adolfo_Aguilar_Zinser_0001.jpg
# data\negative\Adolfo_Aguilar_Zinser_0002.jpg
# data\negative\Adolfo_Aguilar_Zinser_0003.jpg
# data\negative\Adolfo_Rodriguez_Saa_0001.jpg
# data\negative\Adolfo_Rodriguez_Saa_0002.jpg
# data\negative\Adoor_Gopalakarishnan_0001.jpg
# data\negative\Adriana_Lima_0001.jpg
# data\negative\Adriana_Perez_Navarro_0001.jpg
# data\negative\Adrianna_Zuzic_0001.jpg
# data\negative\Adrian_Annus_0001.jpg
# data\negative\Adrian_Fernandez_0001.jpg
# data\negative\Adrian_McPherson_0001.jpg
# data\negative\Adrian_McPherson_0002.jpg
# data\negative\Adrian_Murrell_0001.jpg
# data\negative\Adrian_Nastase_0001.jpg
# data\negative\Adrian_Nastase_0002.jpg
# data\negative\Adrien_Brody_0001.jpg
# data\negative\Adrien_Brody_0002.jpg
# data\negative\Adrien_Brody_0003.jpg
# data\negative\Adrien_Brody_0004.jpg
# data\negative\Adrien_Brody_0005.jpg
# data\negative\Adrien_Brody_0006.jpg
# data\negative\Adrien_Brody_0007.jpg
# data\negative\Adrien_Brody_0008.jpg
# data\negative\Adrien_Brody_0009.jpg
# data\negative\Adrien_Brody_0010.jpg
# data\negative\Adrien_Brody_0011.jpg
# data\negative\Adrien_Brody_0012.jpg
# data\negative\Afton_Smith_0001.jpg
# data\negative\Agbani_Darego_0001.jpg
# data\negative\Agnelo_Queiroz_0001.jpg
# data\negative\Agnes_Bruckner_0001.jpg
# data\negative\Ahmad_Jbarah_0001.jpg
# data\negative\Ahmad_Masood_0001.jpg
# data\negative\Ahmad_Masood_0002.jpg
# data\negative\Ahmed_Ahmed_0001.jpg
# data\negative\Ahmed_Chalabi_0001.jpg
# data\negative\Ahmed_Chalabi_0002.jpg
# data\negative\Ahmed_Chalabi_0003.jpg
# data\negative\Ahmed_Chalabi_0004.jpg
# data\negative\Ahmed_Chalabi_0005.jpg
# data\negative\Ahmed_Ghazi_0001.jpg
# data\negative\Ahmed_Ibrahim_Bilal_0001.jpg
# data\negative\Ahmed_Lopez_0001.jpg
# data\negative\Ahmed_Qureia_0001.jpg
# data\negative\Ahmet_Demir_0001.jpg
# data\negative\Ahmet_Necdet_Sezer_0001.jpg
# data\negative\Ahmet_Necdet_Sezer_0002.jpg
# data\negative\Aicha_El_Ouafi_0001.jpg
# data\negative\Aicha_El_Ouafi_0002.jpg
# data\negative\Aicha_El_Ouafi_0003.jpg
# data\negative\Aidan_Quinn_0001.jpg
# data\negative\Aileen_Riggin_Soule_0001.jpg
# data\negative\Ainsworth_Dyer_0001.jpg
# data\negative\Ain_Seppik_0001.jpg
# data\negative\Aishwarya_Rai_0001.jpg
# data\negative\Aitor_Gonzalez_0001.jpg
# data\negative\Aitor_Gonzalez_0002.jpg
# data\negative\Aiysha_Smith_0001.jpg
# data\negative\Ai_Sugiyama_0001.jpg
# data\negative\Ai_Sugiyama_0002.jpg
# data\negative\Ai_Sugiyama_0003.jpg
# data\negative\Ai_Sugiyama_0004.jpg
# data\negative\Ai_Sugiyama_0005.jpg
# data\negative\Ajit_Agarkar_0001.jpg
# data\negative\AJ_Cook_0001.jpg
# data\negative\AJ_Lamas_0001.jpg
# data\negative\Akbar_Al_Baker_0001.jpg
# data\negative\Akbar_Hashemi_Rafsanjani_0001.jpg
# data\negative\Akbar_Hashemi_Rafsanjani_0002.jpg
# data\negative\Akbar_Hashemi_Rafsanjani_0003.jpg
# data\negative\Akhmed_Zakayev_0001.jpg
# data\negative\Akhmed_Zakayev_0002.jpg
# data\negative\Akhmed_Zakayev_0003.jpg
# data\negative\Akiko_Morigami_0001.jpg
# data\negative\Akmal_Taher_0001.jpg
# data\negative\Alain_Cervantes_0001.jpg
# data\negative\Alain_Ducasse_0001.jpg
# data\negative\Alanis_Morissette_0001.jpg
# data\negative\Alanna_Ubach_0001.jpg
# data\negative\Alan_Ball_0001.jpg
# data\negative\Alan_Ball_0002.jpg
# data\negative\Alan_Dershowitz_0001.jpg
# data\negative\Alan_Dreher_0001.jpg
# data\negative\Alan_Greenspan_0001.jpg
# data\negative\Alan_Greenspan_0002.jpg
# data\negative\Alan_Greenspan_0003.jpg
# data\negative\Alan_Greenspan_0004.jpg
# data\negative\Alan_Greenspan_0005.jpg
# data\negative\Alan_Greer_0001.jpg
# data\negative\Alan_Jackson_0001.jpg
# data\negative\Alan_Mulally_0001.jpg
# data\negative\Alan_Mulally_0002.jpg
# data\negative\Alan_Stonecipher_0001.jpg
# data\negative\Alan_Tang_Kwong-wing_0001.jpg
# data\negative\Alan_Trammell_0001.jpg
# data\negative\Alan_Zemaitis_0001.jpg
# data\negative\Alastair_Campbell_0001.jpg
# data\negative\Alastair_Campbell_0002.jpg
# data\negative\Alastair_Campbell_0003.jpg
# data\negative\Alastair_Campbell_0004.jpg
# data\negative\Alastair_Campbell_0005.jpg
# data\negative\Alastair_Johnston_0001.jpg
# data\negative\Albaro_Recoba_0001.jpg
# data\negative\Alberta_Lee_0001.jpg
# data\negative\Alberto_Acosta_0001.jpg
# data\negative\Alberto_Fujimori_0001.jpg
# data\negative\Alberto_Fujimori_0002.jpg
# data\negative\Alberto_Gonzales_0001.jpg
# data\negative\Alberto_Ruiz_Gallardon_0001.jpg
# data\negative\Alberto_Ruiz_Gallardon_0002.jpg
# data\negative\Alberto_Sordi_0001.jpg
# data\negative\Albert_Brooks_0001.jpg
# data\negative\Albert_Costa_0001.jpg
# data\negative\Albert_Costa_0002.jpg
# data\negative\Albert_Costa_0003.jpg
# data\negative\Albert_Costa_0004.jpg
# data\negative\Albert_Costa_0005.jpg
# data\negative\Albert_Costa_0006.jpg
# data\negative\Albert_Montanes_0001.jpg
# data\negative\Albert_Pujols_0001.jpg
# data\negative\Albrecht_Mentz_0001.jpg
# data\negative\Albrecht_Mentz_0002.jpg
# data\negative\Aldo_Paredes_0001.jpg
# data\negative\Aldo_Paredes_0002.jpg
# data\negative\Alecos_Markides_0001.jpg
# data\negative\Alec_Baldwin_0001.jpg
# data\negative\Alec_Baldwin_0002.jpg
# data\negative\Alec_Baldwin_0003.jpg
# data\negative\Alec_Baldwin_0004.jpg
# data\negative\Alejandro_Atchugarry_0001.jpg
# data\negative\Alejandro_Atchugarry_0002.jpg
# data\negative\Alejandro_Avila_0001.jpg
# data\negative\Alejandro_Avila_0002.jpg
# data\negative\Alejandro_Avila_0003.jpg
# data\negative\Alejandro_Fernandez_0001.jpg
# data\negative\Alejandro_Gonzalez_Inarritu_0001.jpg
# data\negative\Alejandro_Lembo_0001.jpg
# data\negative\Alejandro_Lerner_0001.jpg
# data\negative\Alejandro_Lopez_0001.jpg
# data\negative\Alejandro_Toledo_0001.jpg
# data\negative\Alejandro_Toledo_0002.jpg
# data\negative\Alejandro_Toledo_0003.jpg
# data\negative\Alejandro_Toledo_0004.jpg
# data\negative\Alejandro_Toledo_0005.jpg
# data\negative\Alejandro_Toledo_0006.jpg
# data\negative\Alejandro_Toledo_0007.jpg
# data\negative\Alejandro_Toledo_0008.jpg
# data\negative\Alejandro_Toledo_0009.jpg
# data\negative\Alejandro_Toledo_0010.jpg
# data\negative\Alejandro_Toledo_0011.jpg
# data\negative\Alejandro_Toledo_0012.jpg
# data\negative\Alejandro_Toledo_0013.jpg
# data\negative\Alejandro_Toledo_0014.jpg
# data\negative\Alejandro_Toledo_0015.jpg
# data\negative\Alejandro_Toledo_0016.jpg
# data\negative\Alejandro_Toledo_0017.jpg
# data\negative\Alejandro_Toledo_0018.jpg
# data\negative\Alejandro_Toledo_0019.jpg
# data\negative\Alejandro_Toledo_0020.jpg
# data\negative\Alejandro_Toledo_0021.jpg
# data\negative\Alejandro_Toledo_0022.jpg
# data\negative\Alejandro_Toledo_0023.jpg
# data\negative\Alejandro_Toledo_0024.jpg
# data\negative\Alejandro_Toledo_0025.jpg
# data\negative\Alejandro_Toledo_0026.jpg
# data\negative\Alejandro_Toledo_0027.jpg
# data\negative\Alejandro_Toledo_0028.jpg
# data\negative\Alejandro_Toledo_0029.jpg
# data\negative\Alejandro_Toledo_0030.jpg
# data\negative\Alejandro_Toledo_0031.jpg
# data\negative\Alejandro_Toledo_0032.jpg
# data\negative\Alejandro_Toledo_0033.jpg
# data\negative\Alejandro_Toledo_0034.jpg
# data\negative\Alejandro_Toledo_0035.jpg
# data\negative\Alejandro_Toledo_0036.jpg
# data\negative\Alejandro_Toledo_0037.jpg
# data\negative\Alejandro_Toledo_0038.jpg
# data\negative\Alejandro_Toledo_0039.jpg
# data\negative\Aleksander_Kwasniewski_0001.jpg
# data\negative\Aleksander_Kwasniewski_0002.jpg
# data\negative\Aleksander_Kwasniewski_0003.jpg
# data\negative\Aleksander_Kwasniewski_0004.jpg
# data\negative\Aleksander_Voloshin_0001.jpg
# data\negative\Alek_Wek_0001.jpg
# data\negative\Alessandra_Cerna_0001.jpg
# data\negative\Alessandro_Nesta_0001.jpg
# data\negative\Alexander_Downer_0001.jpg
# data\negative\Alexander_Downer_0002.jpg
# data\negative\Alexander_Downer_0003.jpg
# data\negative\Alexander_Downer_0004.jpg
# data\negative\Alexander_Losyukov_0001.jpg
# data\negative\Alexander_Losyukov_0002.jpg
# data\negative\Alexander_Losyukov_0003.jpg
# data\negative\Alexander_Losyukov_0004.jpg
# data\negative\Alexander_Lukashenko_0001.jpg
# data\negative\Alexander_Payne_0001.jpg
# data\negative\Alexander_Rumyantsev_0001.jpg
# data\negative\Alexander_Rumyantsev_0002.jpg
# data\negative\Alexandra_Jackson_0001.jpg
# data\negative\Alexandra_Pelosi_0001.jpg
# data\negative\Alexandra_Rozovskaya_0001.jpg
# data\negative\Alexandra_Spann_0001.jpg
# data\negative\Alexandra_Stevenson_0001.jpg
# data\negative\Alexandra_Stevenson_0002.jpg
# data\negative\Alexandra_Stevenson_0003.jpg
# data\negative\Alexandra_Vodjanikova_0001.jpg
# data\negative\Alexandra_Vodjanikova_0002.jpg
# data\negative\Alexandre_Daigle_0001.jpg
# data\negative\Alexandre_Despatie_0001.jpg
# data\negative\Alexandre_Herchcovitch_0001.jpg
# data\negative\Alexandre_Vinokourov_0001.jpg
# data\negative\Alexa_Loren_0001.jpg
# data\negative\Alexa_Vega_0001.jpg
# data\negative\Alexis_Bledel_0001.jpg
# data\negative\Alexis_Dennisoff_0001.jpg
# data\negative\Alex_Barros_0001.jpg
# data\negative\Alex_Barros_0002.jpg
# data\negative\Alex_Cabrera_0001.jpg
# data\negative\Alex_Cejka_0001.jpg
# data\negative\Alex_Corretja_0001.jpg
# data\negative\Alex_Ferguson_0001.jpg
# data\negative\Alex_Gonzalez_0001.jpg
# data\negative\Alex_Holmes_0001.jpg
# data\negative\Alex_King_0001.jpg
# data\negative\Alex_Penelas_0001.jpg
# data\negative\Alex_Penelas_0002.jpg
# data\negative\Alex_Popov_0001.jpg
# data\negative\Alex_Sink_0001.jpg
# data\negative\Alex_Sink_0002.jpg
# data\negative\Alex_Sink_0003.jpg
# data\negative\Alex_Wallau_0001.jpg
# data\negative\Alex_Zanardi_0001.jpg
# data\negative\Alfonso_Cuaron_0001.jpg
# data\negative\Alfonso_Portillo_0001.jpg
# data\negative\Alfonso_Soriano_0001.jpg
# data\negative\Alfredo_di_Stefano_0001.jpg
# data\negative\Alfredo_Moreno_0001.jpg
# data\negative\Alfredo_Pena_0001.jpg
# data\negative\Alfred_Ford_0001.jpg
# data\negative\Alfred_Sant_0001.jpg
# data\negative\Alice_Fisher_0001.jpg
# data\negative\Alice_Fisher_0002.jpg
# data\negative\Alicia_Hollowell_0001.jpg
# data\negative\Alicia_Keys_0001.jpg
# data\negative\Alicia_Molik_0001.jpg
# data\negative\Alicia_Silverstone_0001.jpg
# data\negative\Alicia_Silverstone_0002.jpg
# data\negative\Alicia_Witt_0001.jpg
# data\negative\Alimzhan_Tokhtakhounov_0001.jpg
# data\negative\Alimzhan_Tokhtakhounov_0002.jpg
# data\negative\Alina_Kabaeva_0001.jpg
# data\negative\Aline_Chretien_0001.jpg
# data\negative\Alisha_Richman_0001.jpg
# data\negative\Alison_Krauss_0001.jpg
# data\negative\Alison_Lohman_0001.jpg
# data\negative\Alison_Lohman_0002.jpg
# data\negative\Alistair_MacDonald_0001.jpg
# data\negative\Ali_Abbas_0001.jpg
# data\negative\Ali_Abbas_0002.jpg
# data\negative\Ali_Abdullah_Saleh_0001.jpg
# data\negative\Ali_Adbul_Karim_Madani_0001.jpg
# data\negative\Ali_Ahmeti_0001.jpg
# data\negative\Ali_Bin_Hussein_0001.jpg
# data\negative\Ali_Fallahian_0001.jpg
# data\negative\Ali_Hammoud_0001.jpg
# data\negative\Ali_Khamenei_0001.jpg
# data\negative\Ali_Khamenei_0002.jpg
# data\negative\Ali_Khamenei_0003.jpg
# data\negative\Ali_Mohammed_Maher_0001.jpg
# data\negative\Ali_Naimi_0001.jpg
# data\negative\Ali_Naimi_0002.jpg
# data\negative\Ali_Naimi_0003.jpg
# data\negative\Ali_Naimi_0004.jpg
# data\negative\Ali_Naimi_0005.jpg
# data\negative\Ali_Naimi_0006.jpg
# data\negative\Ali_Naimi_0007.jpg
# data\negative\Ali_Naimi_0008.jpg
# data\negative\Allan_Houston_0001.jpg
# data\negative\Allan_Kemakeza_0001.jpg
# data\negative\Allan_Wagner_0001.jpg
# data\negative\Allen_Iverson_0001.jpg
# data\negative\Allen_Iverson_0002.jpg
# data\negative\Allen_Rock_0001.jpg
# data\negative\Allison_Janney_0001.jpg
# data\negative\Allison_Janney_0002.jpg
# data\negative\Allison_Searing_0001.jpg
# data\negative\Allyson_Felix_0001.jpg
# data\negative\Allyson_Felix_0002.jpg
# data\negative\Allyson_Felix_0003.jpg
# data\negative\Allyson_Felix_0004.jpg
# data\negative\Allyson_Felix_0005.jpg
# data\negative\Ally_Sheedy_0001.jpg
# data\negative\Alma_Powell_0001.jpg
# data\negative\Almeida_Baptista_0001.jpg
# data\negative\Alonzo_Mourning_0001.jpg
# data\negative\Alvaro_Noboa_0001.jpg
# data\negative\Alvaro_Noboa_0002.jpg
# data\negative\Alvaro_Noboa_0003.jpg
# data\negative\Alvaro_Silva_Calderon_0001.jpg
# data\negative\Alvaro_Silva_Calderon_0002.jpg
# data\negative\Alvaro_Silva_Calderon_0003.jpg
# data\negative\Alvaro_Silva_Calderon_0004.jpg
# data\negative\Alvaro_Uribe_0001.jpg
# data\negative\Alvaro_Uribe_0002.jpg
# data\negative\Alvaro_Uribe_0003.jpg
# data\negative\Alvaro_Uribe_0004.jpg
# data\negative\Alvaro_Uribe_0005.jpg
# data\negative\Alvaro_Uribe_0006.jpg
# data\negative\Alvaro_Uribe_0007.jpg
# data\negative\Alvaro_Uribe_0008.jpg
# data\negative\Alvaro_Uribe_0009.jpg
# data\negative\Alvaro_Uribe_0010.jpg
# data\negative\Alvaro_Uribe_0011.jpg
# data\negative\Alvaro_Uribe_0012.jpg
# data\negative\Alvaro_Uribe_0013.jpg
# data\negative\Alvaro_Uribe_0014.jpg
# data\negative\Alvaro_Uribe_0015.jpg
# data\negative\Alvaro_Uribe_0016.jpg
# data\negative\Alvaro_Uribe_0017.jpg
# data\negative\Alvaro_Uribe_0018.jpg
# data\negative\Alvaro_Uribe_0019.jpg
# data\negative\Alvaro_Uribe_0020.jpg
# data\negative\Alvaro_Uribe_0021.jpg
# data\negative\Alvaro_Uribe_0022.jpg
# data\negative\Alvaro_Uribe_0023.jpg
# data\negative\Alvaro_Uribe_0024.jpg
# data\negative\Alvaro_Uribe_0025.jpg
# data\negative\Alvaro_Uribe_0026.jpg
# data\negative\Alvaro_Uribe_0027.jpg
# data\negative\Alvaro_Uribe_0028.jpg
# data\negative\Alvaro_Uribe_0029.jpg
# data\negative\Alvaro_Uribe_0030.jpg
# data\negative\Alvaro_Uribe_0031.jpg
# data\negative\Alvaro_Uribe_0032.jpg
# data\negative\Alvaro_Uribe_0033.jpg
# data\negative\Alvaro_Uribe_0034.jpg
# data\negative\Alvaro_Uribe_0035.jpg
# data\negative\Alyse_Beaupre_0001.jpg
# data\negative\Alyson_Hannigan_0001.jpg
# data\negative\Aly_Wagner_0001.jpg
# data\negative\Al_Cardenas_0001.jpg
# data\negative\Al_Davis_0001.jpg
# data\negative\Al_Davis_0002.jpg
# data\negative\Al_Gore_0001.jpg
# data\negative\Al_Gore_0002.jpg
# data\negative\Al_Gore_0003.jpg
# data\negative\Al_Gore_0004.jpg
# data\negative\Al_Gore_0005.jpg
# data\negative\Al_Gore_0006.jpg
# data\negative\Al_Gore_0007.jpg
# data\negative\Al_Gore_0008.jpg
# data\negative\Al_Leiter_0001.jpg
# data\negative\Al_Pacino_0001.jpg
# data\negative\Al_Pacino_0002.jpg
# data\negative\Al_Pacino_0003.jpg
# data\negative\Al_Sharpton_0001.jpg
# data\negative\Al_Sharpton_0002.jpg
# data\negative\Al_Sharpton_0003.jpg
# data\negative\Al_Sharpton_0004.jpg
# data\negative\Al_Sharpton_0005.jpg
# data\negative\Al_Sharpton_0006.jpg
# data\negative\Al_Sharpton_0007.jpg
# data\negative\Amanda_Beard_0001.jpg
# data\negative\Amanda_Beard_0002.jpg
# data\negative\Amanda_Bynes_0001.jpg
# data\negative\Amanda_Bynes_0002.jpg
# data\negative\Amanda_Bynes_0003.jpg
# data\negative\Amanda_Bynes_0004.jpg
# data\negative\Amanda_Coetzer_0001.jpg
# data\negative\Amanda_Coetzer_0002.jpg
# data\negative\Amanda_Marsh_0001.jpg
# data\negative\Amanda_Plumer_0001.jpg
# data\negative\Amber_Frey_0001.jpg
# data\negative\Amber_Tamblyn_0001.jpg
# data\negative\Amber_Tamblyn_0002.jpg
# data\negative\Ambrose_Lee_0001.jpg
# data\negative\Amelia_Vega_0001.jpg
# data\negative\Amelia_Vega_0002.jpg
# data\negative\Amelia_Vega_0003.jpg
# data\negative\Amelia_Vega_0004.jpg
# data\negative\Amelia_Vega_0005.jpg
# data\negative\Amelia_Vega_0006.jpg
# data\negative\Amelia_Vega_0007.jpg
# data\negative\Amelie_Mauresmo_0001.jpg
# data\negative\Amelie_Mauresmo_0002.jpg
# data\negative\Amelie_Mauresmo_0003.jpg
# data\negative\Amelie_Mauresmo_0004.jpg
# data\negative\Amelie_Mauresmo_0005.jpg
# data\negative\Amelie_Mauresmo_0006.jpg
# data\negative\Amelie_Mauresmo_0007.jpg
# data\negative\Amelie_Mauresmo_0008.jpg
# data\negative\Amelie_Mauresmo_0009.jpg
# data\negative\Amelie_Mauresmo_0010.jpg
# data\negative\Amelie_Mauresmo_0011.jpg
# data\negative\Amelie_Mauresmo_0012.jpg
# data\negative\Amelie_Mauresmo_0013.jpg
# data\negative\Amelie_Mauresmo_0014.jpg
# data\negative\Amelie_Mauresmo_0015.jpg
# data\negative\Amelie_Mauresmo_0016.jpg
# data\negative\Amelie_Mauresmo_0017.jpg
# data\negative\Amelie_Mauresmo_0018.jpg
# data\negative\Amelie_Mauresmo_0019.jpg
# data\negative\Amelie_Mauresmo_0020.jpg
# data\negative\Amelie_Mauresmo_0021.jpg
# data\negative\Amer_al-Saadi_0001.jpg
# data\negative\Amer_al-Saadi_0002.jpg
# data\negative\Amer_al-Saadi_0003.jpg
# data\negative\Amer_al-Saadi_0004.jpg
# data\negative\Amporn_Falise_0001.jpg
# data\negative\Amram_Mitzna_0001.jpg
# data\negative\Amram_Mitzna_0002.jpg
# data\negative\Amr_Moussa_0001.jpg
# data\negative\Amy_Brenneman_0001.jpg
# data\negative\Amy_Cotton_0001.jpg
# data\negative\Amy_Gale_0001.jpg
# data\negative\Amy_Pascal_0001.jpg
# data\negative\Amy_Redford_0001.jpg
# data\negative\Amy_Smart_0001.jpg
# data\negative\Amy_Yasbeck_0001.jpg
# data\negative\Anastasia_Kelesidou_0001.jpg
# data\negative\Anastasia_Myskina_0001.jpg
# data\negative\Anastasia_Myskina_0002.jpg
# data\negative\Anastasia_Myskina_0003.jpg
# data\negative\Anatoliy_Kinakh_0001.jpg
# data\negative\Ana_Claudia_Talancon_0001.jpg
# data\negative\Ana_Guevara_0001.jpg
# data\negative\Ana_Guevara_0002.jpg
# data\negative\Ana_Guevara_0003.jpg
# data\negative\Ana_Guevara_0004.jpg
# data\negative\Ana_Guevara_0005.jpg
# data\negative\Ana_Guevara_0006.jpg
# data\negative\Ana_Guevara_0007.jpg
# data\negative\Ana_Isabel_Sanchez_0001.jpg
# data\negative\Ana_Palacio_0001.jpg
# data\negative\Ana_Palacio_0002.jpg
# data\negative\Ana_Palacio_0003.jpg
# data\negative\Ana_Palacio_0004.jpg
# data\negative\Ana_Palacio_0005.jpg
# data\negative\Ana_Palacio_0006.jpg
# data\negative\Ana_Palacio_0007.jpg
# data\negative\Ana_Palacio_0008.jpg
# data\negative\Ana_Paula_Gerard_0001.jpg
# data\negative\Ana_Sebastiao_0001.jpg
# data\negative\Anderson_Varejao_0001.jpg
# data\negative\Anders_Ebbeson_0001.jpg
# data\negative\Anders_Ebbeson_0002.jpg
# data\negative\Anders_Ebbeson_0003.jpg
# data\negative\Anders_Fogh_Rasmussen_0001.jpg
# data\negative\Anders_Fogh_Rasmussen_0002.jpg
# data\negative\Anders_Fogh_Rasmussen_0003.jpg
# data\negative\Anders_Fogh_Rasmussen_0004.jpg
# data\negative\Andreas_Vinciguerra_0001.jpg
# data\negative\Andrea_Bocelli_0001.jpg
# data\negative\Andrea_De_Cruz_0001.jpg
# data\negative\Andrea_Kiser_0001.jpg
# data\negative\Andrea_Yates_0001.jpg
# data\negative\Andrei_Konchalovsky_0001.jpg
# data\negative\Andrei_Mikhnevich_0001.jpg
# data\negative\Andrei_Mikhnevich_0002.jpg
# data\negative\Andrei_Nikolishin_0001.jpg
# data\negative\Andres_DAlessandro_0001.jpg
# data\negative\Andres_Manuel_Lopez_Obrador_0001.jpg
# data\negative\Andres_Pastrana_0001.jpg
# data\negative\Andrew_Bernard_0001.jpg
# data\negative\Andrew_Bunner_0001.jpg
# data\negative\Andrew_Bunner_0002.jpg
# data\negative\Andrew_Caldecott_0001.jpg
# data\negative\Andrew_Cuomo_0001.jpg
# data\negative\Andrew_Cuomo_0002.jpg
# data\negative\Andrew_Fastow_0001.jpg
# data\negative\Andrew_Firestone_0001.jpg
# data\negative\Andrew_Gilligan_0001.jpg
# data\negative\Andrew_Jarecki_0001.jpg
# data\negative\Andrew_Luster_0001.jpg
# data\negative\Andrew_Niccol_0001.jpg
# data\negative\Andrew_Niccol_0002.jpg
# data\negative\Andrew_Sabey_0001.jpg
# data\negative\Andrew_Shutley_0001.jpg
# data\negative\Andrew_Weissmann_0001.jpg
# data\negative\Andrew_Weissmann_0002.jpg
# data\negative\Andrew_Weissmann_0003.jpg
# data\negative\Andrew_Wetzler_0001.jpg
# data\negative\Andre_Agassi_0001.jpg
# data\negative\Andre_Agassi_0002.jpg
# data\negative\Andre_Agassi_0003.jpg
# data\negative\Andre_Agassi_0004.jpg
# data\negative\Andre_Agassi_0005.jpg
# data\negative\Andre_Agassi_0006.jpg
# data\negative\Andre_Agassi_0007.jpg
# data\negative\Andre_Agassi_0008.jpg
# data\negative\Andre_Agassi_0009.jpg
# data\negative\Andre_Agassi_0010.jpg
# data\negative\Andre_Agassi_0011.jpg
# data\negative\Andre_Agassi_0012.jpg
# data\negative\Andre_Agassi_0013.jpg
# data\negative\Andre_Agassi_0014.jpg
# data\negative\Andre_Agassi_0015.jpg
# data\negative\Andre_Agassi_0016.jpg
# data\negative\Andre_Agassi_0017.jpg
# data\negative\Andre_Agassi_0018.jpg
# data\negative\Andre_Agassi_0019.jpg
# data\negative\Andre_Agassi_0020.jpg
# data\negative\Andre_Agassi_0021.jpg
# data\negative\Andre_Agassi_0022.jpg
# data\negative\Andre_Agassi_0023.jpg
# data\negative\Andre_Agassi_0024.jpg
# data\negative\Andre_Agassi_0025.jpg
# data\negative\Andre_Agassi_0026.jpg
# data\negative\Andre_Agassi_0027.jpg
# data\negative\Andre_Agassi_0028.jpg
# data\negative\Andre_Agassi_0029.jpg
# data\negative\Andre_Agassi_0030.jpg
# data\negative\Andre_Agassi_0031.jpg
# data\negative\Andre_Agassi_0032.jpg
# data\negative\Andre_Agassi_0033.jpg
# data\negative\Andre_Agassi_0034.jpg
# data\negative\Andre_Agassi_0035.jpg
# data\negative\Andre_Agassi_0036.jpg
# data\negative\Andre_Bucher_0001.jpg
# data\negative\Andre_Lange_0001.jpg
# data\negative\Andre_Smith_0001.jpg
# data\negative\Andre_Techine_0001.jpg
# data\negative\Andrzej_Tyszkiewicz_0001.jpg
# data\negative\Andy_Benes_0001.jpg
# data\negative\Andy_Bryant_0001.jpg
# data\negative\Andy_Dick_0001.jpg
# data\negative\Andy_Garcia_0001.jpg
# data\negative\Andy_Graves_0001.jpg
# data\negative\Andy_Griffith_0001.jpg
# data\negative\Andy_Griggs_0001.jpg
# data\negative\Andy_Hebb_0001.jpg
# data\negative\Andy_Hebb_0002.jpg
# data\negative\Andy_Lau_0001.jpg
# data\negative\Andy_Madikians_0001.jpg
# data\negative\Andy_North_0001.jpg
# data\negative\Andy_Perez_0001.jpg
# data\negative\Andy_Roddick_0001.jpg
# data\negative\Andy_Roddick_0002.jpg
# data\negative\Andy_Roddick_0003.jpg
# data\negative\Andy_Roddick_0004.jpg
# data\negative\Andy_Roddick_0005.jpg
# data\negative\Andy_Roddick_0006.jpg
# data\negative\Andy_Roddick_0007.jpg
# data\negative\Andy_Roddick_0008.jpg
# data\negative\Andy_Roddick_0009.jpg
# data\negative\Andy_Roddick_0010.jpg
# data\negative\Andy_Roddick_0011.jpg
# data\negative\Andy_Roddick_0012.jpg
# data\negative\Andy_Roddick_0013.jpg
# data\negative\Andy_Roddick_0014.jpg
# data\negative\Andy_Roddick_0015.jpg
# data\negative\Andy_Rooney_0001.jpg
# data\negative\Andy_Warhol_0001.jpg
# data\negative\Andy_Wisecarver_0001.jpg
# data\negative\Anette_Hosoi_0001.jpg
# data\negative\AnFernce_Negron_0001.jpg
# data\negative\Angela_Alvarado_Rosa_0001.jpg
# data\negative\Angela_Bassett_0001.jpg
# data\negative\Angela_Bassett_0002.jpg
# data\negative\Angela_Bassett_0003.jpg
# data\negative\Angela_Bassett_0004.jpg
# data\negative\Angela_Bassett_0005.jpg
# data\negative\Angela_Bassett_0006.jpg
# data\negative\Angela_Lansbury_0001.jpg
# data\negative\Angela_Lansbury_0002.jpg
# data\negative\Angela_Mascia-Frye_0001.jpg
# data\negative\Angela_Merkel_0001.jpg
# data\negative\Angela_Merkel_0002.jpg
# data\negative\Angela_Merkel_0003.jpg
# data\negative\Angela_Merkel_0004.jpg
# data\negative\Angela_Merkel_0005.jpg
# data\negative\Angelica_Romero_0001.jpg
# data\negative\Angelina_Jolie_0001.jpg
# data\negative\Angelina_Jolie_0002.jpg
# data\negative\Angelina_Jolie_0003.jpg
# data\negative\Angelina_Jolie_0004.jpg
# data\negative\Angelina_Jolie_0005.jpg
# data\negative\Angelina_Jolie_0006.jpg
# data\negative\Angelina_Jolie_0007.jpg
# data\negative\Angelina_Jolie_0008.jpg
# data\negative\Angelina_Jolie_0009.jpg
# data\negative\Angelina_Jolie_0010.jpg
# data\negative\Angelina_Jolie_0011.jpg
# data\negative\Angelina_Jolie_0012.jpg
# data\negative\Angelina_Jolie_0013.jpg
# data\negative\Angelina_Jolie_0014.jpg
# data\negative\Angelina_Jolie_0015.jpg
# data\negative\Angelina_Jolie_0016.jpg
# data\negative\Angelina_Jolie_0017.jpg
# data\negative\Angelina_Jolie_0018.jpg
# data\negative\Angelina_Jolie_0019.jpg
# data\negative\Angelina_Jolie_0020.jpg
# data\negative\Angelo_Genova_0001.jpg
# data\negative\Angelo_Reyes_0001.jpg
# data\negative\Angelo_Reyes_0002.jpg
# data\negative\Angelo_Reyes_0003.jpg
# data\negative\Angelo_Reyes_0004.jpg
# data\negative\Angel_Lockward_0001.jpg
# data\negative\Angel_Maza_0001.jpg
# data\negative\Angie_Arzola_0001.jpg
# data\negative\Angie_Martinez_0001.jpg
# data\negative\Anibal_Ibarra_0001.jpg
# data\negative\Anibal_Ibarra_0002.jpg
# data\negative\Anibal_Ibarra_0003.jpg
# data\negative\Anil_Ramsook_0001.jpg
# data\negative\Anita_DeFrantz_0001.jpg
# data\negative\Anja_Paerson_0001.jpg
# data\negative\Anjum_Hussain_0001.jpg
# data\negative\Anna_Chicherova_0001.jpg
# data\negative\Anna_Faris_0001.jpg
# data\negative\Anna_Jones_0001.jpg
# data\negative\Anna_Kournikova_0001.jpg
# data\negative\Anna_Kournikova_0002.jpg
# data\negative\Anna_Kournikova_0003.jpg
# data\negative\Anna_Kournikova_0004.jpg
# data\negative\Anna_Kournikova_0005.jpg
# data\negative\Anna_Kournikova_0006.jpg
# data\negative\Anna_Kournikova_0007.jpg
# data\negative\Anna_Kournikova_0008.jpg
# data\negative\Anna_Kournikova_0009.jpg
# data\negative\Anna_Kournikova_0010.jpg
# data\negative\Anna_Kournikova_0011.jpg
# data\negative\Anna_Kournikova_0012.jpg
# data\negative\Anna_Nicole_Smith_0001.jpg
# data\negative\Anna_Nicole_Smith_0002.jpg
# data\negative\Anneli_Jaatteenmaki_0001.jpg
# data\negative\Anneli_Jaatteenmaki_0002.jpg
# data\negative\Annette_Bening_0001.jpg
# data\negative\Annette_Bening_0002.jpg
# data\negative\Annette_Lu_0001.jpg
# data\negative\Annette_Lu_0002.jpg
# data\negative\Annette_Lu_0003.jpg
# data\negative\Anne_Cavers_0001.jpg
# data\negative\Anne_Donovan_0001.jpg
# data\negative\Anne_Heche_0001.jpg
# data\negative\Anne_Krueger_0001.jpg
# data\negative\Anne_Krueger_0002.jpg
# data\negative\Anne_Krueger_0003.jpg
# data\negative\Anne_McLellan_0001.jpg
# data\negative\Anne_McLellan_0002.jpg
# data\negative\Anne_McLellan_0003.jpg
# data\negative\Anne_ONeil_0001.jpg
# data\negative\Annie-Jeanne_Reynaud_0001.jpg
# data\negative\Annie_Chaplin_0001.jpg
# data\negative\Annie_Machon_0001.jpg
# data\negative\Annika_Sorenstam_0001.jpg
# data\negative\Ann_Godbehere_0001.jpg
# data\negative\Ann_Landers_0001.jpg
# data\negative\Ann_Morgan_0001.jpg
# data\negative\Ann_Veneman_0001.jpg
# data\negative\Ann_Veneman_0002.jpg
# data\negative\Ann_Veneman_0003.jpg
# data\negative\Ann_Veneman_0004.jpg
# data\negative\Ann_Veneman_0005.jpg
# data\negative\Ann_Veneman_0006.jpg
# data\negative\Ann_Veneman_0007.jpg
# data\negative\Ann_Veneman_0008.jpg
# data\negative\Ann_Veneman_0009.jpg
# data\negative\Ann_Veneman_0010.jpg
# data\negative\Ann_Veneman_0011.jpg
# data\negative\Antanas_Valionis_0001.jpg
# data\negative\Anthony_Carter_0001.jpg
# data\negative\Anthony_Corso_0001.jpg
# data\negative\Anthony_Ervin_0001.jpg
# data\negative\Anthony_Fauci_0001.jpg
# data\negative\Anthony_Fauci_0002.jpg
# data\negative\Anthony_Garotinho_0001.jpg
# data\negative\Anthony_Hazen_0001.jpg
# data\negative\Anthony_Hopkins_0001.jpg
# data\negative\Anthony_Hopkins_0002.jpg
# data\negative\Anthony_LaPaglia_0001.jpg
# data\negative\Anthony_LaPaglia_0002.jpg
# data\negative\Anthony_Lee_Johnson_0001.jpg
# data\negative\Anthony_Mazur_0001.jpg
# data\negative\Anthony_Pico_0001.jpg
# data\negative\Anthony_Pisciotti_0001.jpg
# data\negative\Anthony_Principi_0001.jpg
# data\negative\Anthony_Rackauckas_0001.jpg
# data\negative\Anthony_Scott_Miller_0001.jpg
# data\negative\Antje_Buschschulte_0001.jpg
# data\negative\Antonio_Banderas_0001.jpg
# data\negative\Antonio_Banderas_0002.jpg
# data\negative\Antonio_Banderas_0003.jpg
# data\negative\Antonio_Banderas_0004.jpg
# data\negative\Antonio_Banderas_0005.jpg
# data\negative\Antonio_Bernardo_0001.jpg
# data\negative\Antonio_Cassano_0001.jpg
# data\negative\Antonio_Catania_0001.jpg
# data\negative\Antonio_Elias_Saca_0001.jpg
# data\negative\Antonio_Palocci_0001.jpg
# data\negative\Antonio_Palocci_0002.jpg
# data\negative\Antonio_Palocci_0003.jpg
# data\negative\Antonio_Palocci_0004.jpg
# data\negative\Antonio_Palocci_0005.jpg
# data\negative\Antonio_Palocci_0006.jpg
# data\negative\Antonio_Palocci_0007.jpg
# data\negative\Antonio_Palocci_0008.jpg
# data\negative\Antonio_Trillanes_0001.jpg
# data\negative\Antonio_Trillanes_0002.jpg
# data\negative\Antonio_Trillanes_0003.jpg
# data\negative\Antony_Leung_0001.jpg
# data\negative\Antony_Leung_0002.jpg
# data\negative\Antony_Leung_0003.jpg
# data\negative\Antony_Leung_0004.jpg
# data\negative\Anton_Balasingham_0001.jpg
# data\negative\Antwun_Echols_0001.jpg
# data\negative\Anwar_Ibrahim_0001.jpg
# data\negative\Anwar_Ibrahim_0002.jpg
# data\negative\Anzori_Kikalishvili_0001.jpg
# data\negative\Aparna_Pillai_0001.jpg
# data\negative\Aram_Adler_0001.jpg
# data\negative\Arantxa_Sanchez-Vicario_0001.jpg
# data\negative\Arantxa_Sanchez-Vicario_0002.jpg
# data\negative\Aretha_Franklin_0001.jpg
# data\negative\Arianna_Huffington_0001.jpg
# data\negative\Arianna_Huffington_0002.jpg
# data\negative\Arianna_Huffington_0003.jpg
# data\negative\Arianna_Huffington_0004.jpg
# data\negative\Ariel_Sharon_0001.jpg
# data\negative\Ariel_Sharon_0002.jpg
# data\negative\Ariel_Sharon_0003.jpg
# data\negative\Ariel_Sharon_0004.jpg
# data\negative\Ariel_Sharon_0005.jpg
# data\negative\Ariel_Sharon_0006.jpg
# data\negative\Ariel_Sharon_0007.jpg
# data\negative\Ariel_Sharon_0008.jpg
# data\negative\Ariel_Sharon_0009.jpg
# data\negative\Ariel_Sharon_0010.jpg
# data\negative\Ariel_Sharon_0011.jpg
# data\negative\Ariel_Sharon_0012.jpg
# data\negative\Ariel_Sharon_0013.jpg
# data\negative\Ariel_Sharon_0014.jpg
# data\negative\Ariel_Sharon_0015.jpg
# data\negative\Ariel_Sharon_0016.jpg
# data\negative\Ariel_Sharon_0017.jpg
# data\negative\Ariel_Sharon_0018.jpg
# data\negative\Ariel_Sharon_0019.jpg
# data\negative\Ariel_Sharon_0020.jpg
# data\negative\Ariel_Sharon_0021.jpg
# data\negative\Ariel_Sharon_0022.jpg
# data\negative\Ariel_Sharon_0023.jpg
# data\negative\Ariel_Sharon_0024.jpg
# data\negative\Ariel_Sharon_0025.jpg
# data\negative\Ariel_Sharon_0026.jpg
# data\negative\Ariel_Sharon_0027.jpg
# data\negative\Ariel_Sharon_0028.jpg
# data\negative\Ariel_Sharon_0029.jpg
# data\negative\Ariel_Sharon_0030.jpg
# data\negative\Ariel_Sharon_0031.jpg
# data\negative\Ariel_Sharon_0032.jpg
# data\negative\Ariel_Sharon_0033.jpg
# data\negative\Ariel_Sharon_0034.jpg
# data\negative\Ariel_Sharon_0035.jpg
# data\negative\Ariel_Sharon_0036.jpg
# data\negative\Ariel_Sharon_0037.jpg
# data\negative\Ariel_Sharon_0038.jpg
# data\negative\Ariel_Sharon_0039.jpg
# data\negative\Ariel_Sharon_0040.jpg
# data\negative\Ariel_Sharon_0041.jpg
# data\negative\Ariel_Sharon_0042.jpg
# data\negative\Ariel_Sharon_0043.jpg
# data\negative\Ariel_Sharon_0044.jpg
# data\negative\Ariel_Sharon_0045.jpg
# data\negative\Ariel_Sharon_0046.jpg
# data\negative\Ariel_Sharon_0047.jpg
# data\negative\Ariel_Sharon_0048.jpg
# data\negative\Ariel_Sharon_0049.jpg
# data\negative\Ariel_Sharon_0050.jpg
# data\negative\Ariel_Sharon_0051.jpg
# data\negative\Ariel_Sharon_0052.jpg
# data\negative\Ariel_Sharon_0053.jpg
# data\negative\Ariel_Sharon_0054.jpg
# data\negative\Ariel_Sharon_0055.jpg
# data\negative\Ariel_Sharon_0056.jpg
# data\negative\Ariel_Sharon_0057.jpg
# data\negative\Ariel_Sharon_0058.jpg
# data\negative\Ariel_Sharon_0059.jpg
# data\negative\Ariel_Sharon_0060.jpg
# data\negative\Ariel_Sharon_0061.jpg
# data\negative\Ariel_Sharon_0062.jpg
# data\negative\Ariel_Sharon_0063.jpg
# data\negative\Ariel_Sharon_0064.jpg
# data\negative\Ariel_Sharon_0065.jpg
# data\negative\Ariel_Sharon_0066.jpg
# data\negative\Ariel_Sharon_0067.jpg
# data\negative\Ariel_Sharon_0068.jpg
# data\negative\Ariel_Sharon_0069.jpg
# data\negative\Ariel_Sharon_0070.jpg
# data\negative\Ariel_Sharon_0071.jpg
# data\negative\Ariel_Sharon_0072.jpg
# data\negative\Ariel_Sharon_0073.jpg
# data\negative\Ariel_Sharon_0074.jpg
# data\negative\Ariel_Sharon_0075.jpg
# data\negative\Ariel_Sharon_0076.jpg
# data\negative\Ariel_Sharon_0077.jpg
# data\negative\Arie_Haan_0001.jpg
# data\negative\Arif_Mardin_0001.jpg
# data\negative\Ari_Bousbib_0001.jpg
# data\negative\Ari_Fleischer_0001.jpg
# data\negative\Ari_Fleischer_0002.jpg
# data\negative\Ari_Fleischer_0003.jpg
# data\negative\Ari_Fleischer_0004.jpg
# data\negative\Ari_Fleischer_0005.jpg
# data\negative\Ari_Fleischer_0006.jpg
# data\negative\Ari_Fleischer_0007.jpg
# data\negative\Ari_Fleischer_0008.jpg
# data\negative\Ari_Fleischer_0009.jpg
# data\negative\Ari_Fleischer_0010.jpg
# data\negative\Ari_Fleischer_0011.jpg
# data\negative\Ari_Fleischer_0012.jpg
# data\negative\Ari_Fleischer_0013.jpg
# data\negative\Arlen_Specter_0001.jpg
# data\negative\Arlen_Specter_0002.jpg
# data\negative\Arlen_Specter_0003.jpg
# data\negative\Armando_Avila_Panchame_0001.jpg
# data\negative\Armando_Calderon_Sol_0001.jpg
# data\negative\Armando_Carrillo_0001.jpg
# data\negative\Armand_Sargen_0001.jpg
# data\negative\Arminio_Fraga_0001.jpg
# data\negative\Arminio_Fraga_0002.jpg
# data\negative\Arminio_Fraga_0003.jpg
# data\negative\Arminio_Fraga_0004.jpg
# data\negative\Arminio_Fraga_0005.jpg
# data\negative\Arminio_Fraga_0006.jpg
# data\negative\Arnaud_Clement_0001.jpg
# data\negative\Arnaud_Clement_0002.jpg
# data\negative\Arnaud_Lagardere_0001.jpg
# data\negative\Arnie_Boehm_0001.jpg
# data\negative\Arnoldo_Aleman_0001.jpg
# data\negative\Arnoldo_Aleman_0002.jpg
# data\negative\Arnoldo_Aleman_0003.jpg
# data\negative\Arnoldo_Aleman_0004.jpg
# data\negative\Arnoldo_Aleman_0005.jpg
# data\negative\Arnold_Palmer_0001.jpg
# data\negative\Arnold_Palmer_0002.jpg
# data\negative\Arnold_Palmer_0003.jpg
# data\negative\Arnold_Schwarzenegger_0001.jpg
# data\negative\Arnold_Schwarzenegger_0002.jpg
# data\negative\Arnold_Schwarzenegger_0003.jpg
# data\negative\Arnold_Schwarzenegger_0004.jpg
# data\negative\Arnold_Schwarzenegger_0005.jpg
# data\negative\Arnold_Schwarzenegger_0006.jpg
# data\negative\Arnold_Schwarzenegger_0007.jpg
# data\negative\Arnold_Schwarzenegger_0008.jpg
# data\negative\Arnold_Schwarzenegger_0009.jpg
# data\negative\Arnold_Schwarzenegger_0010.jpg
# data\negative\Arnold_Schwarzenegger_0011.jpg
# data\negative\Arnold_Schwarzenegger_0012.jpg
# data\negative\Arnold_Schwarzenegger_0013.jpg
# data\negative\Arnold_Schwarzenegger_0014.jpg
# data\negative\Arnold_Schwarzenegger_0015.jpg
# data\negative\Arnold_Schwarzenegger_0016.jpg
# data\negative\Arnold_Schwarzenegger_0017.jpg
# data\negative\Arnold_Schwarzenegger_0018.jpg
# data\negative\Arnold_Schwarzenegger_0019.jpg
# data\negative\Arnold_Schwarzenegger_0020.jpg
# data\negative\Arnold_Schwarzenegger_0021.jpg
# data\negative\Arnold_Schwarzenegger_0022.jpg
# data\negative\Arnold_Schwarzenegger_0023.jpg
# data\negative\Arnold_Schwarzenegger_0024.jpg
# data\negative\Arnold_Schwarzenegger_0025.jpg
# data\negative\Arnold_Schwarzenegger_0026.jpg
# data\negative\Arnold_Schwarzenegger_0027.jpg
# data\negative\Arnold_Schwarzenegger_0028.jpg
# data\negative\Arnold_Schwarzenegger_0029.jpg
# data\negative\Arnold_Schwarzenegger_0030.jpg
# data\negative\Arnold_Schwarzenegger_0031.jpg
# data\negative\Arnold_Schwarzenegger_0032.jpg
# data\negative\Arnold_Schwarzenegger_0033.jpg
# data\negative\Arnold_Schwarzenegger_0034.jpg
# data\negative\Arnold_Schwarzenegger_0035.jpg
# data\negative\Arnold_Schwarzenegger_0036.jpg
# data\negative\Arnold_Schwarzenegger_0037.jpg
# data\negative\Arnold_Schwarzenegger_0038.jpg
# data\negative\Arnold_Schwarzenegger_0039.jpg
# data\negative\Arnold_Schwarzenegger_0040.jpg
# data\negative\Arnold_Schwarzenegger_0041.jpg
# data\negative\Arnold_Schwarzenegger_0042.jpg
# data\negative\Arnold_Scott_0001.jpg
# data\negative\Aron_Ralston_0001.jpg
# data\negative\Aron_Ralston_0002.jpg
# data\negative\Arsinee_Khanjian_0001.jpg
# data\negative\Arsinee_Khanjian_0002.jpg
# data\negative\Arthur_Johnson_0001.jpg
# data\negative\Arthur_Martinez_0001.jpg
# data\negative\Artieas_Shanks_0001.jpg
# data\negative\Arturo_Gatti_0001.jpg
# data\negative\Arturo_Gatti_0002.jpg
# data\negative\Arturo_Gatti_0003.jpg
# data\negative\Art_Cooper_0001.jpg
# data\negative\Art_Hoffmann_0001.jpg
# data\negative\Art_Hoffmann_0002.jpg
# data\negative\Art_Howe_0001.jpg
# data\negative\Art_Howe_0002.jpg
# data\negative\Art_Howe_0003.jpg
# data\negative\Art_Howe_0004.jpg
# data\negative\Art_Lopez_0001.jpg
# data\negative\Arye_Mekel_0001.jpg
# data\negative\Arye_Mekel_0002.jpg
# data\negative\Asa_Hutchinson_0001.jpg
# data\negative\Asa_Hutchinson_0002.jpg
# data\negative\Ascencion_Barajas_0001.jpg
# data\negative\Ashanti_0001.jpg
# data\negative\Ashanti_0002.jpg
# data\negative\Ashanti_0003.jpg
# data\negative\Ashanti_0004.jpg
# data\negative\Ashanti_0005.jpg
# data\negative\Ashlea_Talbot_0001.jpg
# data\negative\Ashley_Judd_0001.jpg
# data\negative\Ashley_Olsen_0001.jpg
# data\negative\Ashley_Postell_0001.jpg
# data\negative\Ashraf_Alasmar_0001.jpg
# data\negative\Ashraf_Ghani_0001.jpg
# data\negative\Ashton_Kutcher_0001.jpg
# data\negative\Ashton_Kutcher_0002.jpg
# data\negative\Ashton_Kutcher_0003.jpg
# data\negative\Asif_Ali_Zardari_0001.jpg
# data\negative\Asif_Hanif_0001.jpg
# data\negative\Askar_Akayev_0001.jpg
# data\negative\Asmaa_Assad_0001.jpg
# data\negative\Assad_Ahmadi_0001.jpg
# data\negative\Astou_Ndiaye-Diatta_0001.jpg
# data\negative\Astrid_Betancourt_0001.jpg
# data\negative\Astrid_Eyzaguirre_0001.jpg
# data\negative\Atal_Bihari_Vajpayee_0001.jpg
# data\negative\Atal_Bihari_Vajpayee_0002.jpg
# data\negative\Atal_Bihari_Vajpayee_0003.jpg
# data\negative\Atal_Bihari_Vajpayee_0004.jpg
# data\negative\Atal_Bihari_Vajpayee_0005.jpg
# data\negative\Atal_Bihari_Vajpayee_0006.jpg
# data\negative\Atal_Bihari_Vajpayee_0007.jpg
# data\negative\Atal_Bihari_Vajpayee_0008.jpg
# data\negative\Atal_Bihari_Vajpayee_0009.jpg
# data\negative\Atal_Bihari_Vajpayee_0010.jpg
# data\negative\Atal_Bihari_Vajpayee_0011.jpg
# data\negative\Atal_Bihari_Vajpayee_0012.jpg
# data\negative\Atal_Bihari_Vajpayee_0013.jpg
# data\negative\Atal_Bihari_Vajpayee_0014.jpg
# data\negative\Atal_Bihari_Vajpayee_0015.jpg
# data\negative\Atal_Bihari_Vajpayee_0016.jpg
# data\negative\Atal_Bihari_Vajpayee_0017.jpg
# data\negative\Atal_Bihari_Vajpayee_0018.jpg
# data\negative\Atal_Bihari_Vajpayee_0019.jpg
# data\negative\Atal_Bihari_Vajpayee_0020.jpg
# data\negative\Atal_Bihari_Vajpayee_0021.jpg
# data\negative\Atal_Bihari_Vajpayee_0022.jpg
# data\negative\Atal_Bihari_Vajpayee_0023.jpg
# data\negative\Atal_Bihari_Vajpayee_0024.jpg
# data\negative\Ataollah_Mohajerani_0001.jpg
# data\negative\Atiabet_Ijan_Amabel_0001.jpg
# data\negative\Atom_Egoyan_0001.jpg
# data\negative\Atsushi_Sato_0001.jpg
# data\negative\Audrey_Lacroix_0001.jpg
# data\negative\Audrey_Sauret_0001.jpg
# data\negative\Augustin_Calleri_0001.jpg
# data\negative\Augustin_Calleri_0002.jpg
# data\negative\Augustin_Calleri_0003.jpg
# data\negative\Augustin_Calleri_0004.jpg
# data\negative\Augusto_Pinochet_0001.jpg
# data\negative\Augusto_Pinochet_0002.jpg
# data\negative\Augusto_Roa_Bastos_0001.jpg
# data\negative\Augusto_Roa_Bastos_0002.jpg
# data\negative\Aung_San_Suu_Kyi_0001.jpg
# data\negative\Aung_San_Suu_Kyi_0002.jpg
# data\negative\Austin_Kearns_0001.jpg
# data\negative\Avril_Lavigne_0001.jpg
# data\negative\Azmi_Bishara_0001.jpg
# data\negative\Azra_Akin_0001.jpg
# data\negative\Azra_Akin_0002.jpg
# data\negative\Azra_Akin_0003.jpg
# data\negative\Azra_Akin_0004.jpg
# data\negative\Babe_Ruth_0001.jpg
# data\negative\Baburam_Bhattari_0001.jpg
# data\negative\Bak_Chang-Ryun_0001.jpg
# data\negative\Barbara_Bach_0001.jpg
# data\negative\Barbara_Becker_0001.jpg
# data\negative\Barbara_Bodine_0001.jpg
# data\negative\Barbara_Boxer_0001.jpg
# data\negative\Barbara_Brezigar_0001.jpg
# data\negative\Barbara_Brezigar_0002.jpg
# data\negative\Barbara_De_Brun_0001.jpg
# data\negative\Barbara_Esbin_0001.jpg
# data\negative\Barbara_Felt-Miller_0001.jpg
# data\negative\Barbara_Roberts_0001.jpg
# data\negative\Barbara_Walters_0001.jpg
# data\negative\Barbara_Walters_0002.jpg
# data\negative\Barbara_Walters_0003.jpg
# data\negative\Barbara_Walters_0004.jpg
# data\negative\Barbora_Strycova_0001.jpg
# data\negative\Barbra_Streisand_0001.jpg
# data\negative\Barbra_Streisand_0002.jpg
# data\negative\Barbra_Streisand_0003.jpg
# data\negative\Barrett_Jackman_0001.jpg
# data\negative\Barrett_Jackman_0002.jpg
# data\negative\Barry_Alvarez_0001.jpg
# data\negative\Barry_Alvarez_0002.jpg
# data\negative\Barry_Bonds_0001.jpg
# data\negative\Barry_Collier_0001.jpg
# data\negative\Barry_Diller_0001.jpg
# data\negative\Barry_Ford_0001.jpg
# data\negative\Barry_Hinson_0001.jpg
# data\negative\Barry_Nakell_0001.jpg
# data\negative\Barry_Switzer_0001.jpg
# data\negative\Barry_Williams_0001.jpg
# data\negative\Barry_Zito_0001.jpg
# data\negative\Barry_Zito_0002.jpg
# data\negative\Bartosz_Kizierowski_0001.jpg
# data\negative\Bart_Freundlich_0001.jpg
# data\negative\Bart_Hendricks_0001.jpg
# data\negative\Barzan_al-Tikriti_0001.jpg
# data\negative\Basdeo_Panday_0001.jpg
# data\negative\Bashar_Assad_0001.jpg
# data\negative\Bashar_Assad_0002.jpg
# data\negative\Bashar_Assad_0003.jpg
# data\negative\Bashar_Assad_0004.jpg
# data\negative\Baz_Luhrmann_0001.jpg
# data\negative\BB_King_0001.jpg
# data\negative\Beatrice_Dalle_0001.jpg
# data\negative\Beatriz_Merino_0001.jpg
# data\negative\Beecher_Ray_Kirby_0001.jpg
# data\negative\Begum_Khaleda_Zia_0001.jpg
# data\negative\Begum_Khaleda_Zia_0002.jpg
# data\negative\Bela_Karolyi_0001.jpg
# data\negative\Benazir_Bhutto_0001.jpg
# data\negative\Benazir_Bhutto_0002.jpg
# data\negative\Benazir_Bhutto_0003.jpg
# data\negative\Benazir_Bhutto_0004.jpg
# data\negative\Benazir_Bhutto_0005.jpg
# data\negative\Benedita_da_Silva_0001.jpg
# data\negative\Benicio_Del_Toro_0001.jpg
# data\negative\Benito_Santiago_0001.jpg
# data\negative\Benjamin_Bratt_0001.jpg
# data\negative\Benjamin_Franklin_0001.jpg
# data\negative\Benjamin_Martinez_0001.jpg
# data\negative\Benjamin_McKenzie_0001.jpg
# data\negative\Benjamin_Netanyahu_0001.jpg
# data\negative\Benjamin_Netanyahu_0002.jpg
# data\negative\Benjamin_Netanyahu_0003.jpg
# data\negative\Benjamin_Netanyahu_0004.jpg
# data\negative\Benjamin_Netanyahu_0005.jpg
# data\negative\Benjamin_Neulander_0001.jpg
# data\negative\Ben_Affleck_0001.jpg
# data\negative\Ben_Affleck_0002.jpg
# data\negative\Ben_Affleck_0003.jpg
# data\negative\Ben_Affleck_0004.jpg
# data\negative\Ben_Affleck_0005.jpg
# data\negative\Ben_Affleck_0006.jpg
# data\negative\Ben_Affleck_0007.jpg
# data\negative\Ben_Betts_0001.jpg
# data\negative\Ben_Braun_0001.jpg
# data\negative\Ben_Broussard_0001.jpg
# data\negative\Ben_Cahoon_0001.jpg
# data\negative\Ben_Chandler_0001.jpg
# data\negative\Ben_Cohen_0001.jpg
# data\negative\Ben_Curtis_0001.jpg
# data\negative\Ben_Curtis_0002.jpg
# data\negative\Ben_Curtis_0003.jpg
# data\negative\Ben_Davis_0001.jpg
# data\negative\Ben_Glisan_0001.jpg
# data\negative\Ben_Glisan_0002.jpg
# data\negative\Ben_Howland_0001.jpg
# data\negative\Ben_Howland_0002.jpg
# data\negative\Ben_Howland_0003.jpg
# data\negative\Ben_Howland_0004.jpg
# data\negative\Ben_Kingsley_0001.jpg
# data\negative\Ben_Lee_0001.jpg
# data\negative\Ben_Stein_0001.jpg
# data\negative\Ben_Wallace_0001.jpg
# data\negative\Bernadette_Peters_0001.jpg
# data\negative\Bernardo_Segura_0001.jpg
# data\negative\Bernardo_Segura_0002.jpg
# data\negative\Bernard_Ebbers_0001.jpg
# data\negative\Bernard_Giraudeau_0001.jpg
# data\negative\Bernard_Kerik_0001.jpg
# data\negative\Bernard_Landry_0001.jpg
# data\negative\Bernard_Landry_0002.jpg
# data\negative\Bernard_Landry_0003.jpg
# data\negative\Bernard_Landry_0004.jpg
# data\negative\Bernard_Law_0001.jpg
# data\negative\Bernard_Law_0002.jpg
# data\negative\Bernard_Law_0003.jpg
# data\negative\Bernard_Law_0004.jpg
# data\negative\Bernard_Law_0005.jpg
# data\negative\Bernard_Lord_0001.jpg
# data\negative\Bernard_Lord_0002.jpg
# data\negative\Bernard_Siegel_0001.jpg
# data\negative\Bernice_Wong_0001.jpg
# data\negative\Bertie_Ahern_0001.jpg
# data\negative\Bertie_Ahern_0002.jpg
# data\negative\Bertie_Ahern_0003.jpg
# data\negative\Bertie_Ahern_0004.jpg
# data\negative\Bertie_Ahern_0005.jpg
# data\negative\Bertrand_Bonello_0001.jpg
# data\negative\Bertrand_Bonello_0002.jpg
# data\negative\Bertrand_Delanoe_0001.jpg
# data\negative\Beth_Blough_0001.jpg
# data\negative\Beth_Jones_0001.jpg
# data\negative\Beth_Jones_0002.jpg
# data\negative\Betsy_Coffin_0001.jpg
# data\negative\Betsy_Smith_0001.jpg
# data\negative\Betsy_Smith_0002.jpg
# data\negative\Bettina_Rheims_0001.jpg
# data\negative\Betty_Garrison_0001.jpg
# data\negative\Betty_Williams_0001.jpg
# data\negative\Beyonce_Knowles_0001.jpg
# data\negative\Bianca_Jagger_0001.jpg
# data\negative\Bijan_Darvish_0001.jpg
# data\negative\Bijan_Darvish_0002.jpg
# data\negative\Bijan_Darvish_0003.jpg
# data\negative\Bijan_Namdar_Zangeneh_0001.jpg
# data\negative\Bijan_Namdar_Zangeneh_0002.jpg
# data\negative\Bilal_Erdogan_0001.jpg
# data\negative\Biljana_Plavsic_0001.jpg
# data\negative\Biljana_Plavsic_0002.jpg
# data\negative\Biljana_Plavsic_0003.jpg
# data\negative\Billy_Andrade_0001.jpg
# data\negative\Billy_Beane_0001.jpg
# data\negative\Billy_Bob_Thornton_0001.jpg
# data\negative\Billy_Boyd_0001.jpg
# data\negative\Billy_Crawford_0001.jpg
# data\negative\Billy_Crystal_0001.jpg
# data\negative\Billy_Crystal_0002.jpg
# data\negative\Billy_Crystal_0003.jpg
# data\negative\Billy_Crystal_0004.jpg
# data\negative\Billy_Crystal_0005.jpg
# data\negative\Billy_Crystal_0006.jpg
# data\negative\Billy_Donovan_0001.jpg
# data\negative\Billy_Edelin_0001.jpg
# data\negative\Billy_Gilman_0001.jpg
# data\negative\Billy_Graham_0001.jpg
# data\negative\Billy_Graham_0002.jpg
# data\negative\Billy_Joel_0001.jpg
# data\negative\Billy_Rork_0001.jpg
# data\negative\Billy_Sollie_0001.jpg
# data\negative\Billy_Sollie_0002.jpg
# data\negative\Billy_Tibbets_0001.jpg
# data\negative\Bill_Belichick_0001.jpg
# data\negative\Bill_Belichick_0002.jpg
# data\negative\Bill_Bradley_0001.jpg
# data\negative\Bill_Butler_0001.jpg
# data\negative\Bill_Byrne_0001.jpg
# data\negative\Bill_Callahan_0001.jpg
# data\negative\Bill_Callahan_0002.jpg
# data\negative\Bill_Callahan_0003.jpg
# data\negative\Bill_Carmody_0001.jpg
# data\negative\Bill_Cartwright_0001.jpg
# data\negative\Bill_Clancy_0001.jpg
# data\negative\Bill_Clinton_0001.jpg
# data\negative\Bill_Clinton_0002.jpg
# data\negative\Bill_Clinton_0003.jpg
# data\negative\Bill_Clinton_0004.jpg
# data\negative\Bill_Clinton_0005.jpg
# data\negative\Bill_Clinton_0006.jpg
# data\negative\Bill_Clinton_0007.jpg
# data\negative\Bill_Clinton_0008.jpg
# data\negative\Bill_Clinton_0009.jpg
# data\negative\Bill_Clinton_0010.jpg
# data\negative\Bill_Clinton_0011.jpg
# data\negative\Bill_Clinton_0012.jpg
# data\negative\Bill_Clinton_0013.jpg
# data\negative\Bill_Clinton_0014.jpg
# data\negative\Bill_Clinton_0015.jpg
# data\negative\Bill_Clinton_0016.jpg
# data\negative\Bill_Clinton_0017.jpg
# data\negative\Bill_Clinton_0018.jpg
# data\negative\Bill_Clinton_0019.jpg
# data\negative\Bill_Clinton_0020.jpg
# data\negative\Bill_Clinton_0021.jpg
# data\negative\Bill_Clinton_0022.jpg
# data\negative\Bill_Clinton_0023.jpg
# data\negative\Bill_Clinton_0024.jpg
# data\negative\Bill_Clinton_0025.jpg
# data\negative\Bill_Clinton_0026.jpg
# data\negative\Bill_Clinton_0027.jpg
# data\negative\Bill_Clinton_0028.jpg
# data\negative\Bill_Clinton_0029.jpg
# data\negative\Bill_Curry_0001.jpg
# data\negative\Bill_Doba_0001.jpg
# data\negative\Bill_Duffey_0001.jpg
# data\negative\Bill_Elliott_0001.jpg
# data\negative\Bill_Fennelly_0001.jpg
# data\negative\Bill_Frist_0001.jpg
# data\negative\Bill_Frist_0002.jpg
# data\negative\Bill_Frist_0003.jpg
# data\negative\Bill_Frist_0004.jpg
# data\negative\Bill_Frist_0005.jpg
# data\negative\Bill_Frist_0006.jpg
# ...
# data\negative\Winona_Ryder_0001.jpg
# data\negative\Winona_Ryder_0002.jpg
# data\negative\Winona_Ryder_0003.jpg
# data\negative\Winona_Ryder_0004.jpg
# data\negative\Winona_Ryder_0005.jpg
# data\negative\Winona_Ryder_0006.jpg
# data\negative\Winona_Ryder_0007.jpg
# data\negative\Winona_Ryder_0008.jpg
# data\negative\Winona_Ryder_0009.jpg
# data\negative\Winona_Ryder_0010.jpg
# data\negative\Winona_Ryder_0011.jpg
# data\negative\Winona_Ryder_0012.jpg
# data\negative\Winona_Ryder_0013.jpg
# data\negative\Winona_Ryder_0014.jpg
# data\negative\Winona_Ryder_0015.jpg
# data\negative\Winona_Ryder_0016.jpg
# data\negative\Winona_Ryder_0017.jpg
# data\negative\Winona_Ryder_0018.jpg
# data\negative\Winona_Ryder_0019.jpg
# data\negative\Winona_Ryder_0020.jpg
# data\negative\Winona_Ryder_0021.jpg
# data\negative\Winona_Ryder_0022.jpg
# data\negative\Winona_Ryder_0023.jpg
# data\negative\Winona_Ryder_0024.jpg
# data\negative\Winston_Churchill_0001.jpg
# data\negative\Win_Aung_0001.jpg
# data\negative\Win_Aung_0002.jpg
# data\negative\Win_Aung_0003.jpg
# data\negative\Win_Aung_0004.jpg
# data\negative\Wolfgang_Becker_0001.jpg
# data\negative\Wolfgang_Clement_0001.jpg
# data\negative\Wolfgang_Schneiderhan_0001.jpg
# data\negative\Wolfgang_Schuessel_0001.jpg
# data\negative\Wolfgang_Schuessel_0002.jpg
# data\negative\Wolfgang_Schuessel_0003.jpg
# data\negative\Wolfgang_Schuessel_0004.jpg
# data\negative\Wolfgang_Schwarz_0001.jpg
# data\negative\Woodrow_Stanley_0001.jpg
# data\negative\Woody_Allen_0001.jpg
# data\negative\Woody_Allen_0002.jpg
# data\negative\Woody_Allen_0003.jpg
# data\negative\Woody_Allen_0004.jpg
# data\negative\Woody_Allen_0005.jpg
# data\negative\Wu_Peng_0001.jpg
# data\negative\Wu_Yi_0001.jpg
# data\negative\Wu_Yi_0002.jpg
# data\negative\Wu_Yi_0003.jpg
# data\negative\Wycliffe_Grousbeck_0001.jpg
# data\negative\Xanana_Gusmao_0001.jpg
# data\negative\Xanana_Gusmao_0002.jpg
# data\negative\Xanana_Gusmao_0003.jpg
# data\negative\Xanana_Gusmao_0004.jpg
# data\negative\Xanana_Gusmao_0005.jpg
# data\negative\Xavier_Malisse_0001.jpg
# data\negative\Xavier_Malisse_0002.jpg
# data\negative\Xavier_Malisse_0003.jpg
# data\negative\Xavier_Malisse_0004.jpg
# data\negative\Xavier_Malisse_0005.jpg
# data\negative\Xiang_Huaicheng_0001.jpg
# data\negative\Xiang_Liu_0001.jpg
# data\negative\Xiang_Xu_0001.jpg
# data\negative\Ximena_Bohorquez_0001.jpg
# data\negative\Yale_Kamisar_0001.jpg
# data\negative\Yana_Klochkova_0001.jpg
# data\negative\Yang_Hee_Kim_0001.jpg
# data\negative\Yang_Jianli_0001.jpg
# data\negative\Yang_Pao-yu_0001.jpg
# data\negative\Yannos_Papantoniou_0001.jpg
# data\negative\Yann_Martel_0001.jpg
# data\negative\Yann_Martel_0002.jpg
# data\negative\Yao_Ming_0001.jpg
# data\negative\Yao_Ming_0002.jpg
# data\negative\Yao_Ming_0003.jpg
# data\negative\Yao_Ming_0004.jpg
# data\negative\Yao_Ming_0005.jpg
# data\negative\Yao_Ming_0006.jpg
# data\negative\Yao_Ming_0007.jpg
# data\negative\Yao_Ming_0008.jpg
# data\negative\Yasar_Yakis_0001.jpg
# data\negative\Yasar_Yakis_0002.jpg
# data\negative\Yasar_Yakis_0003.jpg
# data\negative\Yasar_Yakis_0004.jpg
# data\negative\Yasein_Taher_0001.jpg
# data\negative\Yashwant_Sinha_0001.jpg
# data\negative\Yashwant_Sinha_0002.jpg
# data\negative\Yashwant_Sinha_0003.jpg
# data\negative\Yashwant_Sinha_0004.jpg
# data\negative\Yashwant_Sinha_0005.jpg
# data\negative\Yashwant_Sinha_0006.jpg
# data\negative\Yashwant_Sinha_0007.jpg
# data\negative\Yasser_Arafat_0001.jpg
# data\negative\Yasser_Arafat_0002.jpg
# data\negative\Yasser_Arafat_0003.jpg
# data\negative\Yasser_Arafat_0004.jpg
# data\negative\Yasser_Arafat_0005.jpg
# data\negative\Yasser_Arafat_0006.jpg
# data\negative\Yasser_Arafat_0007.jpg
# data\negative\Yasser_Arafat_0008.jpg
# data\negative\Yasushi_Akashi_0001.jpg
# data\negative\Yasushi_Chimura_0001.jpg
# data\negative\Yekaterina_Guseva_0001.jpg
# data\negative\Yevgeny_Kafelnikov_0001.jpg
# data\negative\Yevgeny_Kafelnikov_0002.jpg
# data\negative\Yevgeny_Kafelnikov_0003.jpg
# data\negative\Yevgeny_Kafelnikov_0004.jpg
# data\negative\Yingfan_Wang_0001.jpg
# data\negative\Yishan_Zhang_0001.jpg
# data\negative\Yoelbi_Quesada_0001.jpg
# data\negative\Yogi_Berra_0001.jpg
# data\negative\Yoko_Ono_0001.jpg
# data\negative\Yoko_Ono_0002.jpg
# data\negative\Yoko_Ono_0003.jpg
# data\negative\Yoko_Ono_0004.jpg
# data\negative\Yoko_Ono_0005.jpg
# data\negative\Yoko_Ono_0006.jpg
# data\negative\Yolanda_King_0001.jpg
# data\negative\Yoon_Jeong_Cho_0001.jpg
# data\negative\Yoon_Jin-Sik_0001.jpg
# data\negative\Yoon_Won-Sik_0001.jpg
# data\negative\Yoon_Young-kwan_0001.jpg
# data\negative\Yoo_Jay-Kun_0001.jpg
# data\negative\Yoriko_Kawaguchi_0001.jpg
# data\negative\Yoriko_Kawaguchi_0002.jpg
# data\negative\Yoriko_Kawaguchi_0003.jpg
# data\negative\Yoriko_Kawaguchi_0004.jpg
# data\negative\Yoriko_Kawaguchi_0005.jpg
# data\negative\Yoriko_Kawaguchi_0006.jpg
# data\negative\Yoriko_Kawaguchi_0007.jpg
# data\negative\Yoriko_Kawaguchi_0008.jpg
# data\negative\Yoriko_Kawaguchi_0009.jpg
# data\negative\Yoriko_Kawaguchi_0010.jpg
# data\negative\Yoriko_Kawaguchi_0011.jpg
# data\negative\Yoriko_Kawaguchi_0012.jpg
# data\negative\Yoriko_Kawaguchi_0013.jpg
# data\negative\Yoriko_Kawaguchi_0014.jpg
# data\negative\Yory_Boy_Campas_0001.jpg
# data\negative\Yoshiyuki_Kamei_0001.jpg
# data\negative\Yossi_Beilin_0001.jpg
# data\negative\Yossi_Beilin_0002.jpg
# data\negative\Young_Kim_0001.jpg
# data\negative\Yukiko_Okudo_0001.jpg
# data\negative\Yukiko_Okudo_0002.jpg
# data\negative\Yukio_Hatoyama_0001.jpg
# data\negative\Yuri_Fedotov_0001.jpg
# data\negative\Yuri_Fedotov_0002.jpg
# data\negative\Yuri_Luzhkov_0001.jpg
# data\negative\Yuri_Malenchenko_0001.jpg
# data\negative\Yuri_Malenchenko_0002.jpg
# data\negative\Yusaku_Miyazato_0001.jpg
# data\negative\Yusuf_Misbac_0001.jpg
# data\negative\Yuvraj_Singh_0001.jpg
# data\negative\Yu_Shyi-kun_0001.jpg
# data\negative\Yu_Shyi-kun_0002.jpg
# data\negative\Yu_Shyi-kun_0003.jpg
# data\negative\Yu_Shyi-kun_0004.jpg
# data\negative\Yves_Brodeur_0001.jpg
# data\negative\Zach_Parise_0001.jpg
# data\negative\Zach_Pillar_0001.jpg
# data\negative\Zach_Safrin_0001.jpg
# data\negative\Zafarullah_Khan_Jamali_0001.jpg
# data\negative\Zafarullah_Khan_Jamali_0002.jpg
# data\negative\Zahir_Shah_0001.jpg
# data\negative\Zaini_Abdullah_0001.jpg
# data\negative\Zakia_Hakki_0001.jpg
# data\negative\Zalmay_Khalilzad_0001.jpg
# data\negative\Zarai_Toledo_0001.jpg
# data\negative\Zarai_Toledo_0002.jpg
# data\negative\Zara_Akhmadova_0001.jpg
# data\negative\Zavad_Zarif_0001.jpg
# data\negative\Zdravko_Mucic_0001.jpg
# data\negative\Zeljko_Rebraca_0001.jpg
# data\negative\Zelma_Novelo_0001.jpg
# data\negative\Zeng_Qinghong_0001.jpg
# data\negative\Zhang_Wenkang_0001.jpg
# data\negative\Zhang_Wenkang_0002.jpg
# data\negative\Zhang_Yimou_0001.jpg
# data\negative\Zhang_Ziyi_0001.jpg
# data\negative\Zhang_Ziyi_0002.jpg
# data\negative\Zhang_Ziyi_0003.jpg
# data\negative\Zhang_Ziyi_0004.jpg
# data\negative\Zhong_Nanshan_0001.jpg
# data\negative\Zhu_Rongji_0001.jpg
# data\negative\Zhu_Rongji_0002.jpg
# data\negative\Zhu_Rongji_0003.jpg
# data\negative\Zhu_Rongji_0004.jpg
# data\negative\Zhu_Rongji_0005.jpg
# data\negative\Zhu_Rongji_0006.jpg
# data\negative\Zhu_Rongji_0007.jpg
# data\negative\Zhu_Rongji_0008.jpg
# data\negative\Zhu_Rongji_0009.jpg
# data\negative\Zico_0001.jpg
# data\negative\Zico_0002.jpg
# data\negative\Zico_0003.jpg
# data\negative\Zinedine_Zidane_0001.jpg
# data\negative\Zinedine_Zidane_0002.jpg
# data\negative\Zinedine_Zidane_0003.jpg
# data\negative\Zinedine_Zidane_0004.jpg
# data\negative\Zinedine_Zidane_0005.jpg
# data\negative\Zinedine_Zidane_0006.jpg
# data\negative\Ziwang_Xu_0001.jpg
# data\negative\Zoe_Ball_0001.jpg
# data\negative\Zoran_Djindjic_0001.jpg
# data\negative\Zoran_Djindjic_0002.jpg
# data\negative\Zoran_Djindjic_0003.jpg
# data\negative\Zoran_Djindjic_0004.jpg
# data\negative\Zorica_Radovic_0001.jpg
# data\negative\Zulfiqar_Ahmed_0001.jpg
# data\negative\Zumrati_Juma_0001.jpg
# data\negative\Zurab_Tsereteli_0001.jpg
# data\negative\Zydrunas_Ilgauskas_0001.jpg
# b'data\\anchor\\a4608ce5-120e-11ee-89c9-ab6017e68633.jpg'
# Model: "embedding"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 100, 100, 3)]     0
#
#  conv2d (Conv2D)             (None, 91, 91, 64)        19264
#
#  max_pooling2d (MaxPooling2D  (None, 46, 46, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 40, 40, 128)       401536
#
#  max_pooling2d_1 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 17, 128)       262272
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 256)         524544
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
# =================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# _________________________________________________________________
# Model: "embedding"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 100, 100, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 91, 91, 64)        19264
#
#  max_pooling2d_3 (MaxPooling  (None, 46, 46, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 40, 40, 128)       401536
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 17, 17, 128)       262272
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)         524544
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_1 (Dense)             (None, 4096)              37752832
#
# =================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# _________________________________________________________________
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_img (InputLayer)         [(None, 100, 100, 3  0           []
#                                 )]
#
#  validation_img (InputLayer)    [(None, 100, 100, 3  0           []
#                                 )]
#
#  embedding (Functional)         (None, 4096)         38960448    ['input_img[0][0]',
#                                                                   'validation_img[0][0]']
#
#  l1_dist_1 (L1Dist)             (None, 4096)         0           ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  dense_2 (Dense)                (None, 1)            4097        ['l1_dist_1[0][0]']
#
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_img (InputLayer)         [(None, 100, 100, 3  0           []
#                                 )]
#
#  validation_img (InputLayer)    [(None, 100, 100, 3  0           []
#                                 )]
#
#  embedding (Functional)         (None, 4096)         38960448    ['input_img[0][0]',
#                                                                   'validation_img[0][0]']
#
#  distance (L1Dist)              (None, 4096)         0           ['embedding[2][0]',
#                                                                   'embedding[3][0]']
#
#  dense_3 (Dense)                (None, 1)            4097        ['distance[0][0]']
#
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
#  Epoch 1/50
# Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 2/3 [===================>..........] - ETA: 44s Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ## 6.1 Import Metrics

# %%
# Import metric calculations
from tensorflow.keras.metrics import Precision, Recall

# %% [markdown]
# ## 6.2 Make Predictions

# %%
# Get a batch of test data
test_input, test_val, y_true = test_data.as_numpy_iterator().next()

# %%
y_hat = siamese_model.predict([test_input, test_val])

# %%
# Post processing the results 
[1 if prediction > 0.5 else 0 for prediction in y_hat ]
# Out:
# [1, 1, 1, 0, 1, 1, 0, 0, 1, 0, 0, 0, 0, 1, 0, 1]

# %%
y_true
# Out:
# array([1., 1., 1., 0., 1., 1., 0., 0., 1., 0., 0., 0., 0., 1., 0., 1.],
#       dtype=float32)

# %% [markdown]
# ## 6.3 Calculate Metrics

# %%
# Creating a metric object 
m = Recall()

# Calculating the recall value 
m.update_state(y_true, y_hat)

# Return Recall Result
m.result().numpy()
# Out:
# 1.0

# %%
# Creating a metric object 
m = Precision()

# Calculating the recall value 
m.update_state(y_true, y_hat)

# Return Recall Result
m.result().numpy()
# Out:
# 1.0

# %%
r = Recall()
p = Precision()

for test_input, test_val, y_true in test_data.as_numpy_iterator():
    yhat = siamese_model.predict([test_input, test_val])
    r.update_state(y_true, yhat)
    p.update_state(y_true,yhat) 

print(r.result().numpy(), p.result().numpy())
# Out:
# 1.0 0.99889135

# %% [markdown]
# ## 6.4 Viz Results

# %%
# Set plot size 
plt.figure(figsize=(10,8))

# Set first subplot
plt.subplot(1,2,1)
plt.imshow(test_input[0])

# Set second subplot
plt.subplot(1,2,2)
plt.imshow(test_val[0])

# Renders cleanly
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
# Save weights
siamese_model.save('siamesemodelv2.h5')

# %%
L1Dist

# %%
# Reload model 
siamese_model = tf.keras.models.load_model('siamesemodelv2.h5', 
                                   custom_objects={'L1Dist':L1Dist, 'BinaryCrossentropy':tf.losses.BinaryCrossentropy})
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# Make predictions with reloaded model
siamese_model.predict([test_input, test_val])
# Out:
# array([[2.7295970e-05],
#        [8.7373185e-01],
#        [1.1476276e-06],
#        [9.9997568e-01],
#        [9.9490523e-01],
#        [2.8164588e-06],
#        [2.9260066e-06],
#        [1.0000000e+00]], dtype=float32)

# %%
# View model summary
siamese_model.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_img (InputLayer)          [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# validation_img (InputLayer)     [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# embedding (Functional)          (None, 4096)         38960448    input_img[0][0]
#                                                                  validation_img[0][0]
# __________________________________________________________________________________________________
# l1_dist_6 (L1Dist)              (None, 4096)         0           embedding[0][0]
#                                                                  embedding[1][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            4097        l1_dist_6[0][0]
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 8. Real Time Test

# %% [markdown]
# ## 8.1 Verification Function

# %%
application_data\verification_images

# %%
os.listdir(os.path.join('application_data', 'verification_images'))

# %%
os.path.join('application_data', 'input_image', 'input_image.jpg')

# %%
for image in os.listdir(os.path.join('application_data', 'verification_images')):
    validation_img = os.path.join('application_data', 'verification_images', image)
    print(validation_img)

# %%
def verify(model, detection_threshold, verification_threshold):
    # Build results array
    results = []
    for image in os.listdir(os.path.join('application_data', 'verification_images')):
        input_img = preprocess(os.path.join('application_data', 'input_image', 'input_image.jpg'))
        validation_img = preprocess(os.path.join('application_data', 'verification_images', image))
        
        # Make Predictions 
        result = model.predict(list(np.expand_dims([input_img, validation_img], axis=1)))
        results.append(result)
    
    # Detection Threshold: Metric above which a prediciton is considered positive 
    detection = np.sum(np.array(results) > detection_threshold)
    
    # Verification Threshold: Proportion of positive predictions / total positive samples 
    verification = detection / len(os.listdir(os.path.join('application_data', 'verification_images'))) 
    verified = verification > verification_threshold
    
    return results, verified

# %% [markdown]
# ## 8.2 OpenCV Real Time Verification

# %%
cap = cv2.VideoCapture(4)
while cap.isOpened():
    ret, frame = cap.read()
    frame = frame[120:120+250,200:200+250, :]
    
    cv2.imshow('Verification', frame)
    
    # Verification trigger
    if cv2.waitKey(10) & 0xFF == ord('v'):
        # Save input image to application_data/input_image folder 
#         hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
#         h, s, v = cv2.split(hsv)

#         lim = 255 - 10
#         v[v > lim] = 255
#         v[v <= lim] -= 10
        
#         final_hsv = cv2.merge((h, s, v))
#         img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)

        cv2.imwrite(os.path.join('application_data', 'input_image', 'input_image.jpg'), frame)
        # Run verification
        results, verified = verify(siamese_model, 0.5, 0.5)
        print(verified)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
np.sum(np.squeeze(results) > 0.9)
# Out:
# 36

# %%
results
# Out:
# [array([[0.9944859]], dtype=float32),
#  array([[0.9999912]], dtype=float32),
#  array([[0.9999943]], dtype=float32),
#  array([[0.9999951]], dtype=float32),
#  array([[0.99993753]], dtype=float32),
#  array([[0.9082498]], dtype=float32),
#  array([[0.9999846]], dtype=float32),
#  array([[0.9834683]], dtype=float32),
#  array([[0.87159216]], dtype=float32),
#  array([[0.7328309]], dtype=float32),
#  array([[0.74533516]], dtype=float32),
#  array([[0.949607]], dtype=float32),
#  array([[0.7501703]], dtype=float32),
#  array([[0.60669833]], dtype=float32),
#  array([[0.93921214]], dtype=float32),
#  array([[0.9813106]], dtype=float32),
#  array([[0.9848625]], dtype=float32),
#  array([[0.89696234]], dtype=float32),
#  array([[0.98896575]], dtype=float32),
#  array([[0.99082947]], dtype=float32),
#  array([[0.7747197]], dtype=float32),
#  array([[0.99999297]], dtype=float32),
#  array([[0.99986887]], dtype=float32),
#  array([[0.9999764]], dtype=float32),
#  array([[0.90808266]], dtype=float32),
#  array([[0.8795649]], dtype=float32),
#  array([[0.9634782]], dtype=float32),
#  array([[0.9790052]], dtype=float32),
#  array([[0.98665583]], dtype=float32),
#  array([[0.98852533]], dtype=float32),
#  array([[0.9995832]], dtype=float32),
#  array([[1.]], dtype=float32),
#  array([[0.9905027]], dtype=float32),
#  array([[0.99841905]], dtype=float32),
#  array([[0.96080494]], dtype=float32),
#  array([[0.8443497]], dtype=float32),
#  array([[0.9721696]], dtype=float32),
#  array([[0.80732024]], dtype=float32),
#  array([[0.79700935]], dtype=float32),
#  array([[0.94146115]], dtype=float32),
#  array([[0.9694269]], dtype=float32),
#  array([[0.902836]], dtype=float32),
#  array([[0.9999974]], dtype=float32),
#  array([[0.9999436]], dtype=float32),
#  array([[0.83173716]], dtype=float32),
#  array([[0.9837488]], dtype=float32),
#  array([[0.9999938]], dtype=float32),
#  array([[0.9960765]], dtype=float32),
#  array([[0.8436094]], dtype=float32),
#  array([[0.78270465]], dtype=float32)]
